# %% [markdown]
# <a href="https://colab.research.google.com/github/AXLCA031/Quimica_UNMSM/blob/main/GASES2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install drawdata
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 12.3 MB/s eta 0:00:00
# ...

# %%
from drawdata import draw_scatter
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
data = [{"x":52.320575181251094,"y":446.9571054562075,"color":"a"},{"x":31.92028954208836,"y":437.4498054392664,"color":"a"},{"x":90.6305243653764,"y":464.6919665815368,"color":"a"},{"x":31.587106224062676,"y":462.2619332799092,"color":"a"},{"x":49.24040731582332,"y":483.33599618925933,"color":"a"},{"x":22.391967844641155,"y":439.2425741015435,"color":"a"},{"x":44.17120671616076,"y":449.51914723331697,"color":"a"},{"x":59.19016191673673,"y":391.4286716535368,"color":"a"},{"x":69.09361118650382,"y":408.94664293421613,"color":"a"},{"x":71.46071506935061,"y":350.9072357565859,"color":"a"},{"x":81.43888490762225,"y":422.7286023784743,"color":"a"},{"x":4.812629354927061,"y":350.2828102012343,"color":"a"},{"x":81.8235277834224,"y":323.9675303531027,"color":"a"},{"x":13.185877042652542,"y":368.0858046404763,"color":"a"},{"x":93.38231869398457,"y":387.65570352501095,"color":"a"},{"x":49.32004274964092,"y":343.67200840637577,"color":"a"},{"x":88.3713869672276,"y":352.17119570538387,"color":"a"},{"x":86.6339430358318,"y":381.5769489230206,"color":"a"},{"x":52.23157720292866,"y":340.94335717184725,"color":"a"},{"x":71.61854675901695,"y":335.8730998720588,"color":"a"},{"x":82.93426565878458,"y":368.8750753857365,"color":"a"},{"x":71.0492359250141,"y":367.9172082244952,"color":"a"},{"x":68.03410389741383,"y":373.09291890599394,"color":"a"},{"x":75.07410711211165,"y":335.7794266080719,"color":"a"},{"x":84.95541548303814,"y":331.5147530469792,"color":"a"},{"x":38.42713285303393,"y":392.1521614214029,"color":"a"},{"x":14.079285396638419,"y":333.556976174208,"color":"a"},{"x":72.11547807878334,"y":322.63648245937327,"color":"a"},{"x":94.4321204659934,"y":327.8219022767794,"color":"a"},{"x":99.68565004664967,"y":333.32098612630256,"color":"a"},{"x":64.41234942030658,"y":301.12683468915714,"color":"a"},{"x":29.074655695967984,"y":309.43592371851247,"color":"a"},{"x":76.44728428774812,"y":352.48181499415426,"color":"a"},{"x":119.42426730298071,"y":309.46731169384344,"color":"a"},{"x":88.0655339154478,"y":305.2991426128699,"color":"a"},{"x":125.68674108712382,"y":309.6603295408057,"color":"a"},{"x":79.37742764886657,"y":361.1811424101997,"color":"a"},{"x":110.48975401553295,"y":299.42885719174967,"color":"a"},{"x":60.28836044531151,"y":304.1872857129774,"color":"a"},{"x":23.21005266990292,"y":315.69847849920563,"color":"a"},{"x":117.28922233537176,"y":287.9011539608595,"color":"a"},{"x":151.41752994012347,"y":269.6827046787015,"color":"a"},{"x":67.78827615600866,"y":301.8291220153692,"color":"a"},{"x":153.60830244186764,"y":204.6749186723015,"color":"a"},{"x":80.86051047237001,"y":261.23366142622126,"color":"a"},{"x":95.35614390383995,"y":260.76330797380894,"color":"a"},{"x":102.936642978483,"y":252.6846434126745,"color":"a"},{"x":112.24903960837662,"y":215.47978453697954,"color":"a"},{"x":131.83457471242176,"y":264.960430458093,"color":"a"},{"x":110.4713976707879,"y":225.99431887108142,"color":"a"},{"x":140.83481624476858,"y":269.38881893777847,"color":"a"},{"x":83.04419536715838,"y":263.71486812312446,"color":"a"},{"x":110.38761934442543,"y":202.24400025570634,"color":"a"},{"x":111.20129293463876,"y":263.5761800422826,"color":"a"},{"x":105.86011538950359,"y":257.8897154702697,"color":"a"},{"x":109.5129742636035,"y":229.02130671444326,"color":"a"},{"x":155.04150800638666,"y":252.66716312277828,"color":"a"},{"x":125.96494541469775,"y":216.00354243629175,"color":"a"},{"x":130.1491129975903,"y":205.26989765454573,"color":"a"},{"x":114.27130907202347,"y":183.94927621102465,"color":"a"},{"x":101.77601270958172,"y":190.46318252305508,"color":"a"},{"x":143.53304725209034,"y":185.93511736383732,"color":"a"},{"x":151.96621349536042,"y":192.45998140634396,"color":"a"},{"x":137.6729249319546,"y":173.43599562459946,"color":"a"},{"x":123.86844277922138,"y":129.35247057988744,"color":"a"},{"x":156.88379452022883,"y":164.5954703084621,"color":"a"},{"x":177.9887271410676,"y":221.77241479291433,"color":"a"},{"x":152.1985126151135,"y":212.83846002794178,"color":"a"},{"x":162.11385234111262,"y":151.5160708294518,"color":"a"},{"x":137.5228426442905,"y":124.8137703601318,"color":"a"},{"x":152.24110797790337,"y":142.77836304371954,"color":"a"},{"x":149.8917247324167,"y":174.6655492181518,"color":"a"},{"x":136.58451222133493,"y":162.3326350590994,"color":"a"},{"x":165.82383948136663,"y":167.74765090194268,"color":"a"},{"x":141.07233824765365,"y":181.05098320851368,"color":"a"},{"x":175.94522727399686,"y":203.34381175668108,"color":"a"},{"x":177.65863829902796,"y":179.45183341250748,"color":"a"},{"x":141.4922870535932,"y":109.44846012878207,"color":"a"},{"x":171.6073078114971,"y":144.10421296066215,"color":"a"},{"x":201.20448751515258,"y":180.7199888443605,"color":"a"},{"x":244.29321305649114,"y":134.50220086456818,"color":"a"},{"x":189.86290644294684,"y":170.04042104884707,"color":"a"},{"x":156.0160046430269,"y":117.37510229063543,"color":"a"},{"x":155.54926528314058,"y":159.9668146159555,"color":"a"},{"x":176.40625049189555,"y":166.3299641894385,"color":"a"},{"x":177.595286702228,"y":200.81637255562902,"color":"a"},{"x":224.6424341948977,"y":133.0464269226821,"color":"a"},{"x":210.0187510488609,"y":152.06076848405985,"color":"a"},{"x":190.34674986566765,"y":141.37609741171696,"color":"a"},{"x":236.30003994612775,"y":133.11365480755455,"color":"a"},{"x":261.2340327822667,"y":148.44904086603327,"color":"a"},{"x":231.25520472836357,"y":105.9645090497167,"color":"a"},{"x":170.9025601572894,"y":93.20539232822921,"color":"a"},{"x":203.43460579111658,"y":121.66732282390251,"color":"a"},{"x":233.02276925087938,"y":134.84914131549095,"color":"a"},{"x":241.5873788260171,"y":144.79734587111835,"color":"a"},{"x":214.44575075533243,"y":179.00789551556238,"color":"a"},{"x":221.80943258226682,"y":115.34243783795671,"color":"a"},{"x":200.08245830649872,"y":104.98892956419348,"color":"a"},{"x":181.61965761034307,"y":98.50880727147057,"color":"a"},{"x":247.0260567250118,"y":51.021133922569106,"color":"a"},{"x":277.73984907983163,"y":103.5141203332982,"color":"a"},{"x":243.2303855229457,"y":97.34619475857147,"color":"a"},{"x":261.6357973447024,"y":120.28430772968323,"color":"a"},{"x":248.95379938876744,"y":74.92999160803993,"color":"a"},{"x":320.9928108443076,"y":82.62254492960506,"color":"a"},{"x":310.6260342959397,"y":91.70663609184851,"color":"a"},{"x":307.2624032150281,"y":125.93379844727309,"color":"a"},{"x":269.2530003158522,"y":112.09137132677284,"color":"a"},{"x":265.23446933379796,"y":143.04811042772337,"color":"a"},{"x":304.40727882884823,"y":84.74677397599663,"color":"a"},{"x":260.4891067326168,"y":110.93765437154377,"color":"a"},{"x":276.28300483951097,"y":99.12850745641299,"color":"a"},{"x":299.17257237751244,"y":91.14500818749127,"color":"a"},{"x":321.8463947905344,"y":102.97861062740157,"color":"a"},{"x":360.31912598584535,"y":85.91515117059248,"color":"a"},{"x":319.83112867686367,"y":112.64584682043494,"color":"a"},{"x":333.74026075562114,"y":137.26274969114502,"color":"a"},{"x":386.637919992921,"y":98.59364911798212,"color":"a"},{"x":369.07860303575745,"y":81.3595790895381,"color":"a"},{"x":327.78156176207847,"y":159.01047382295314,"color":"a"},{"x":361.01699736256995,"y":86.88307306604219,"color":"a"},{"x":345.6893429068448,"y":87.46202916277025,"color":"a"},{"x":338.09369608052276,"y":77.0745699073089,"color":"a"},{"x":370.1326980027535,"y":107.46308766357458,"color":"a"},{"x":382.0892677783155,"y":134.43199723227366,"color":"a"},{"x":373.0481365012645,"y":50.48496582996171,"color":"a"},{"x":436.0121453557054,"y":85.4085934573501,"color":"a"},{"x":375.5309356690626,"y":144.471419432012,"color":"a"},{"x":422.9029225984801,"y":107.04156675634277,"color":"a"},{"x":438.1029525559545,"y":62.93575071249995,"color":"a"},{"x":401.3614086162059,"y":69.25627048675295,"color":"a"},{"x":431.9973333171614,"y":63.72085807028259,"color":"a"},{"x":427.70620901249964,"y":86.46010927262802,"color":"a"},{"x":428.37086181790824,"y":103.86477279929136,"color":"a"},{"x":434.66245398646834,"y":106.52732837781281,"color":"a"},{"x":409.66925441424667,"y":46.80222664228347,"color":"a"},{"x":431.21557435932317,"y":128.93178329515354,"color":"a"},{"x":456.45113934410506,"y":122.34665212754396,"color":"a"},{"x":449.61731283827754,"y":69.68464722948869,"color":"a"},{"x":470.656189161367,"y":68.99852717029381,"color":"a"},{"x":441.81585335784933,"y":88.30852955053405,"color":"a"},{"x":422.66347515114177,"y":90.06714998634197,"color":"a"},{"x":443.3126004046461,"y":75.80233724864587,"color":"a"},{"x":477.4066091273441,"y":81.00778804994638,"color":"a"},{"x":467.78113620760246,"y":89.74469229589545,"color":"a"},{"x":542.9543401646538,"y":88.35104819117004,"color":"a"},{"x":408.90404988460523,"y":85.1788124271061,"color":"a"},{"x":451.9940471041661,"y":73.66524267031491,"color":"a"},{"x":501.9530036245865,"y":117.17333452287653,"color":"a"},{"x":467.10640434515733,"y":74.50478328199057,"color":"a"},{"x":456.4964154168819,"y":142.85734461777616,"color":"a"},{"x":552.480264559375,"y":73.71853569513809,"color":"a"},{"x":459.6213510156324,"y":77.29411996742095,"color":"a"},{"x":500.91764107686186,"y":110.91132674770614,"color":"a"},{"x":547.5231715767426,"y":86.66919995248162,"color":"a"},{"x":547.7781159486972,"y":96.86477228282496,"color":"a"},{"x":563.6156612857227,"y":34.072953575617476,"color":"a"},{"x":478.62978997129176,"y":95.3905190709159,"color":"a"},{"x":488.21023121109846,"y":92.42282346038621,"color":"a"},{"x":574.2267987832477,"y":59.60194813181715,"color":"a"},{"x":521.1704756166743,"y":77.16732457356932,"color":"a"},{"x":530.1338240664193,"y":96.94538214207637,"color":"a"},{"x":546.1547119054516,"y":81.35379390012497,"color":"a"},{"x":528.4204918849772,"y":67.48986994512887,"color":"a"},{"x":530.8123277306508,"y":65.61612758144577,"color":"a"},{"x":535.5186769122137,"y":146.01617151751702,"color":"a"},{"x":529.9268075974272,"y":63.1781221026568,"color":"a"},{"x":567.4390477742227,"y":67.35001173643047,"color":"a"},{"x":553.3105310965765,"y":49.00296786346854,"color":"a"},{"x":512.0912801017472,"y":115.85873120005158,"color":"a"},{"x":561.041866016199,"y":117.0441859881771,"color":"a"},{"x":567.6372702737903,"y":93.7365263048244,"color":"a"},{"x":564.855462309593,"y":45.17355639782011,"color":"a"},{"x":535.5467391690008,"y":74.82070066931897,"color":"a"},{"x":509.93107832529313,"y":142.873146141054,"color":"a"},{"x":475.5168182167369,"y":68.73525884327103,"color":"a"},{"x":544.1042315018558,"y":139.4514518525956,"color":"a"},{"x":501.31183718945124,"y":62.83594413122984,"color":"a"},{"x":534.0995874867441,"y":108.45583528505887,"color":"a"},{"x":528.4596881393597,"y":99.12747610219299,"color":"a"},{"x":577.7924910259133,"y":91.10094723943871,"color":"a"},{"x":583.6686678075937,"y":97.45907459846836,"color":"a"},{"x":539.5937163047247,"y":79.5455028456214,"color":"a"},{"x":611.8449713521235,"y":112.24474560990035,"color":"a"},{"x":579.2214465738915,"y":80.63811097313044,"color":"a"},{"x":575.6061721962125,"y":80.42595567375298,"color":"a"},{"x":557.0886269598157,"y":136.56147387524925,"color":"a"},{"x":631.9544638459168,"y":123.75883458445782,"color":"a"},{"x":585.1502851097903,"y":102.21722955213454,"color":"a"},{"x":531.2083489487931,"y":97.19811896138572,"color":"a"},{"x":572.2889091607166,"y":75.72959472912777,"color":"a"},{"x":602.4629283711831,"y":102.15987303335123,"color":"a"},{"x":610.0379541794912,"y":75.10796068015861,"color":"a"},{"x":611.2816899487933,"y":25.733541961460674,"color":"a"},{"x":614.5669504388811,"y":94.40371677001963,"color":"a"},{"x":621.1129360928907,"y":79.23054529423752,"color":"a"},{"x":564.7558108741281,"y":111.22405031986045,"color":"a"},{"x":618.2280624783897,"y":87.18205641112553,"color":"a"},{"x":652.0441720975333,"y":116.8031214236413,"color":"a"},{"x":621.1990983184604,"y":114.87745991550315,"color":"a"},{"x":608.7508581146122,"y":72.31887149692085,"color":"a"},{"x":590.0551808420573,"y":66.10130779480966,"color":"a"},{"x":634.8236999492813,"y":93.21907005341433,"color":"a"},{"x":628.8721896610775,"y":87.04353214870679,"color":"a"},{"x":631.5946987179738,"y":85.02154434390877,"color":"a"},{"x":616.5712908995331,"y":98.02370875422861,"color":"a"},{"x":625.4066027101136,"y":110.56530475514757,"color":"a"},{"x":628.7488788897195,"y":84.52785228713356,"color":"a"},{"x":616.4021756576853,"y":66.67425638040487,"color":"a"},{"x":651.8662974130724,"y":106.37362270556252,"color":"a"},{"x":666.0164600335131,"y":141.0848798114884,"color":"a"},{"x":604.3837839577808,"y":75.90412728885292,"color":"a"},{"x":632.7103527327826,"y":131.12779522921147,"color":"a"},{"x":635.0418224549459,"y":41.621045651884515,"color":"a"},{"x":636.9244907888564,"y":92.52623923894635,"color":"a"},{"x":618.6809463083317,"y":105.44827613757872,"color":"a"},{"x":638.8676785133168,"y":119.98869350331057,"color":"a"},{"x":651.1988256617808,"y":109.64080093622135,"color":"a"}]
df = pd.DataFrame.from_dict(data, orient='columns')

plt.scatter(df["x"],df["y"])
plt.xlabel("Volumen (Litros)")
plt.ylabel("Presión (atm)")
plt.title("Ley de Boyle")
# Out:
# Text(0.5, 1.0, 'Ley de Boyle')

# %%
data = [{"x":16.220466487011123,"y":19.07394856842359,"color":"a"},{"x":-5.967959593182375,"y":14.311976801154287,"color":"a"},{"x":-36.71313293038706,"y":56.363507914541174,"color":"a"},{"x":25.38522362148703,"y":-8.972918383321598,"color":"a"},{"x":82.72140304364942,"y":40.787471770712216,"color":"a"},{"x":7.99419900643295,"y":9.117048049093569,"color":"a"},{"x":5.140869196032604,"y":19.284009090874235,"color":"a"},{"x":19.27267453391113,"y":-19.226731744684685,"color":"a"},{"x":29.652403725463845,"y":22.368613790605707,"color":"a"},{"x":43.979490027180404,"y":44.537952985916945,"color":"a"},{"x":-15.465028598136804,"y":1.461198901851219,"color":"a"},{"x":-11.785928600856117,"y":55.98421650982556,"color":"a"},{"x":46.5135050703931,"y":62.6691462235828,"color":"a"},{"x":76.90402315105274,"y":73.86933228463374,"color":"a"},{"x":66.06034160152868,"y":56.010704643449515,"color":"a"},{"x":100.69397330958299,"y":89.15024509540694,"color":"a"},{"x":68.33342265981621,"y":39.83654047392537,"color":"a"},{"x":95.31565819704792,"y":61.428352449285455,"color":"a"},{"x":26.41447083486399,"y":78.3792697843723,"color":"a"},{"x":57.7294694652993,"y":64.62602262730269,"color":"a"},{"x":129.62585801139952,"y":60.617517140084715,"color":"a"},{"x":52.63785553276169,"y":64.21082053534957,"color":"a"},{"x":83.88233925817464,"y":44.93249786938844,"color":"a"},{"x":79.96217354784083,"y":70.92165595202323,"color":"a"},{"x":80.31623635141523,"y":50.913532882864615,"color":"a"},{"x":58.99213804653164,"y":49.48796862807313,"color":"a"},{"x":84.5528746281868,"y":92.61294738632188,"color":"a"},{"x":87.14199975452692,"y":124.78792838184285,"color":"a"},{"x":128.90915298117199,"y":76.5744688229326,"color":"a"},{"x":68.33401986925975,"y":99.69348551430426,"color":"a"},{"x":96.94997952914495,"y":121.8917844281346,"color":"a"},{"x":124.99147948820325,"y":58.51192509919787,"color":"a"},{"x":97.75344543632158,"y":108.78961405340038,"color":"a"},{"x":143.0979032619104,"y":74.09483802352963,"color":"a"},{"x":104.93045392516511,"y":84.37363455168457,"color":"a"},{"x":86.95516895997454,"y":96.16981687965125,"color":"a"},{"x":127.90616280976246,"y":93.55281058217957,"color":"a"},{"x":101.86684464507915,"y":121.97618137152551,"color":"a"},{"x":121.66492352189502,"y":123.70806554293694,"color":"a"},{"x":98.696942071309,"y":141.53550359074404,"color":"a"},{"x":65.96778830616839,"y":124.69921305035683,"color":"a"},{"x":99.67794295722572,"y":114.67927467968093,"color":"a"},{"x":84.62918721910766,"y":103.47232429790711,"color":"a"},{"x":140.26500389725433,"y":159.59556104178176,"color":"a"},{"x":107.7853995848427,"y":121.84085345525114,"color":"a"},{"x":160.17234317552823,"y":172.89107926130305,"color":"a"},{"x":162.71488335446912,"y":100.44874027046069,"color":"a"},{"x":139.7471561763034,"y":150.54080607083137,"color":"a"},{"x":130.91591893827368,"y":148.95329203773906,"color":"a"},{"x":176.87928976887508,"y":156.15157175593475,"color":"a"},{"x":168.63073387430254,"y":179.9443998233295,"color":"a"},{"x":107.3422523525598,"y":168.3518333093329,"color":"a"},{"x":114.01994054420155,"y":149.00914451549403,"color":"a"},{"x":184.52329764171125,"y":45.85552096417791,"color":"a"},{"x":136.28604902074647,"y":117.48738249857541,"color":"a"},{"x":144.34801701786398,"y":136.16266507419414,"color":"a"},{"x":186.38769945648232,"y":153.33030328418278,"color":"a"},{"x":132.13939133181898,"y":169.899814065962,"color":"a"},{"x":139.02669202821616,"y":177.91120312413273,"color":"a"},{"x":161.47503672499948,"y":152.20277403213373,"color":"a"},{"x":138.83333016335618,"y":102.89301213992826,"color":"a"},{"x":165.83193388890825,"y":133.91820921061787,"color":"a"},{"x":179.22330238222483,"y":149.01295654057515,"color":"a"},{"x":173.52011642702342,"y":168.80983840585685,"color":"a"},{"x":143.25978460613248,"y":155.6388113065646,"color":"a"},{"x":164.80545364576304,"y":138.86008930068846,"color":"a"},{"x":180.65464778677148,"y":129.3963188044229,"color":"a"},{"x":143.75259831912365,"y":131.1383281799133,"color":"a"},{"x":166.1574528134753,"y":171.94115463402449,"color":"a"},{"x":175.65213889371583,"y":164.22523625993557,"color":"a"},{"x":156.77643558264788,"y":212.86565060068608,"color":"a"},{"x":186.74001519830375,"y":153.11148105163807,"color":"a"},{"x":140.2931536049578,"y":150.2793486593938,"color":"a"},{"x":191.80091203225734,"y":147.75098811853485,"color":"a"},{"x":201.6784686572669,"y":157.61591721303103,"color":"a"},{"x":166.80949454844966,"y":139.59691419066803,"color":"a"},{"x":154.47586995251592,"y":168.28841036303254,"color":"a"},{"x":186.8668739489146,"y":169.8353344036293,"color":"a"},{"x":175.22206564277687,"y":155.5759065751525,"color":"a"},{"x":175.4620545092824,"y":205.90000592980135,"color":"a"},{"x":214.51882870450402,"y":170.28260939644457,"color":"a"},{"x":160.6736190422795,"y":150.54561857747586,"color":"a"},{"x":182.60177624029996,"y":175.6707609180209,"color":"a"},{"x":162.98502576341713,"y":178.81996297570862,"color":"a"},{"x":192.51076805359804,"y":198.58679410396513,"color":"a"},{"x":203.4442273832398,"y":154.00662353521352,"color":"a"},{"x":150.74034956597697,"y":164.80419329846524,"color":"a"},{"x":184.65180045779732,"y":181.2946598690064,"color":"a"},{"x":185.53640668636146,"y":192.13403662626223,"color":"a"},{"x":203.96519524617653,"y":153.0554199534949,"color":"a"},{"x":188.1752163122124,"y":202.15943066731694,"color":"a"},{"x":203.2985893752325,"y":209.5207102992631,"color":"a"},{"x":205.74168123564553,"y":220.69670877636594,"color":"a"},{"x":229.6930386743856,"y":183.31839501030464,"color":"a"},{"x":181.50999137730096,"y":169.5112604286046,"color":"a"},{"x":222.78091309151688,"y":192.56977034622798,"color":"a"},{"x":225.37601312305588,"y":198.7690411766772,"color":"a"},{"x":185.61893360984067,"y":194.04377253721566,"color":"a"},{"x":211.4043810436191,"y":195.72384537220546,"color":"a"},{"x":237.48852802301923,"y":195.9749433155484,"color":"a"},{"x":224.24666487486908,"y":223.40746200004247,"color":"a"},{"x":268.6180075472061,"y":213.7778619326931,"color":"a"},{"x":184.56038460635887,"y":194.16163391211398,"color":"a"},{"x":197.84523444682335,"y":190.76457679334408,"color":"a"},{"x":212.1280916292103,"y":202.3544145533421,"color":"a"},{"x":189.22566433868644,"y":218.55554885044558,"color":"a"},{"x":216.2544116342447,"y":173.62034640359354,"color":"a"},{"x":204.0023071277195,"y":216.0362493332483,"color":"a"},{"x":227.04016236364882,"y":243.8423469638917,"color":"a"},{"x":224.99290100679744,"y":231.64972628173552,"color":"a"},{"x":243.74240344415935,"y":224.30939878092676,"color":"a"},{"x":224.10480927678356,"y":250.30430673321752,"color":"a"},{"x":226.77389147668896,"y":248.14211478151287,"color":"a"},{"x":211.18576949568683,"y":237.31892900518045,"color":"a"},{"x":252.2133223820617,"y":205.1025978276707,"color":"a"},{"x":206.35929657745294,"y":235.18256701827835,"color":"a"},{"x":215.6072655463251,"y":229.34779125814794,"color":"a"},{"x":268.7602026850902,"y":249.20517151730192,"color":"a"},{"x":246.54804779790646,"y":175.17247438320828,"color":"a"},{"x":210.238316946032,"y":252.92085524214104,"color":"a"},{"x":246.14334284559408,"y":230.3985835282042,"color":"a"},{"x":206.77973994478654,"y":230.71069602541957,"color":"a"},{"x":250.10746824815845,"y":204.7678490846696,"color":"a"},{"x":250.57087808316373,"y":219.69111401203998,"color":"a"},{"x":249.48633386635626,"y":249.88230343003983,"color":"a"},{"x":263.8919344898306,"y":213.5301075126511,"color":"a"},{"x":244.38784454589702,"y":238.74340868109869,"color":"a"},{"x":246.95666176477258,"y":273.6873865233634,"color":"a"},{"x":307.58644571405245,"y":241.82264032053985,"color":"a"},{"x":169.56495546684386,"y":157.61179516393935,"color":"a"},{"x":200.05087914916544,"y":186.95509625416378,"color":"a"},{"x":278.42380873814164,"y":254.6889755951812,"color":"a"},{"x":237.2858766273598,"y":291.545655479973,"color":"a"},{"x":264.2791990166641,"y":291.05401100220627,"color":"a"},{"x":259.8106120163239,"y":264.8637715306312,"color":"a"},{"x":312.93258092805314,"y":268.5751285265514,"color":"a"},{"x":246.30006936407307,"y":269.88458740584286,"color":"a"},{"x":258.36593186948727,"y":256.9453872635561,"color":"a"},{"x":222.83298352871262,"y":206.16572539375125,"color":"a"},{"x":277.02328845760434,"y":274.73100406980586,"color":"a"},{"x":310.66831253826933,"y":277.54827421128044,"color":"a"},{"x":278.9544978097409,"y":270.47772979136454,"color":"a"},{"x":253.42078886037052,"y":222.01347551485668,"color":"a"},{"x":243.6456687754524,"y":269.70263783730917,"color":"a"},{"x":236.6326248779952,"y":262.08335194874013,"color":"a"},{"x":255.06451545611887,"y":262.9951695688928,"color":"a"},{"x":288.1131101228682,"y":248.25674586202933,"color":"a"},{"x":263.6532467131934,"y":305.12416547921254,"color":"a"},{"x":273.88337722450126,"y":278.1069170371054,"color":"a"},{"x":263.282996584733,"y":233.20623807445543,"color":"a"},{"x":250.67771057056646,"y":301.10753481638994,"color":"a"},{"x":274.9919836857413,"y":261.9431624428636,"color":"a"},{"x":248.3891490026462,"y":344.7016272764898,"color":"a"},{"x":295.2735610471709,"y":258.16852112964153,"color":"a"},{"x":253.3954775592473,"y":307.20246831960515,"color":"a"},{"x":312.6946958765192,"y":260.24930634322646,"color":"a"},{"x":277.9463795135322,"y":286.3479500400048,"color":"a"},{"x":244.71740700090987,"y":310.62417799011666,"color":"a"},{"x":300.88949819875944,"y":296.43249804963614,"color":"a"},{"x":273.6067204404671,"y":279.5098757897274,"color":"a"},{"x":282.40920283259317,"y":285.77364662854177,"color":"a"},{"x":280.9229392654022,"y":287.51534150490875,"color":"a"},{"x":281.87858198006376,"y":326.86762048218577,"color":"a"},{"x":285.1519940378023,"y":303.29805127554243,"color":"a"},{"x":301.3403292670745,"y":278.06499615611415,"color":"a"},{"x":301.03193264332896,"y":309.0323472016926,"color":"a"},{"x":274.1969621039369,"y":268.22839259623333,"color":"a"},{"x":311.58256661823816,"y":312.7268018460726,"color":"a"},{"x":334.7912603702849,"y":300.7773886527361,"color":"a"},{"x":302.17797604623087,"y":331.99280575572004,"color":"a"},{"x":302.6283012055358,"y":321.3657433054236,"color":"a"},{"x":333.0196703678303,"y":308.21084150839755,"color":"a"},{"x":298.16744201290186,"y":279.3873684886283,"color":"a"},{"x":299.31979546034574,"y":313.8473908226549,"color":"a"},{"x":316.15922062968895,"y":297.54184982935635,"color":"a"},{"x":347.6463792596789,"y":312.0014548275201,"color":"a"},{"x":323.86153102142646,"y":261.0711255257045,"color":"a"},{"x":318.0654191437441,"y":299.64086516866996,"color":"a"},{"x":307.5726412972328,"y":334.9118374057688,"color":"a"},{"x":292.67052516803176,"y":328.72435334357147,"color":"a"},{"x":307.3705909487258,"y":323.2848653604923,"color":"a"},{"x":354.797805984549,"y":309.8814054570911,"color":"a"},{"x":312.3601724966285,"y":305.2779295983149,"color":"a"},{"x":250.74284517436132,"y":288.31149779778394,"color":"a"},{"x":335.3528615433243,"y":307.44783249622753,"color":"a"},{"x":346.17317848950853,"y":325.8160492402733,"color":"a"},{"x":305.4757786348804,"y":323.1652645440479,"color":"a"},{"x":327.1905634478003,"y":350.70541761449954,"color":"a"},{"x":320.73438696743375,"y":382.1103905612381,"color":"a"},{"x":343.9037039564356,"y":340.46095321842097,"color":"a"},{"x":349.39061027269526,"y":311.71125285122685,"color":"a"},{"x":314.46209850124745,"y":278.9015156098051,"color":"a"},{"x":322.09425773870606,"y":311.1995899546078,"color":"a"},{"x":303.6210486397478,"y":301.72081045609,"color":"a"},{"x":319.83932666914984,"y":351.05981067573634,"color":"a"},{"x":354.23071811554206,"y":401.68672558829826,"color":"a"},{"x":361.2812808781711,"y":329.157762663599,"color":"a"},{"x":317.37786184809545,"y":361.2055348712654,"color":"a"},{"x":367.78480758601654,"y":331.50948489980874,"color":"a"},{"x":370.6498075776517,"y":259.8510293097917,"color":"a"},{"x":336.23216998146694,"y":311.61344974603486,"color":"a"},{"x":367.83365346634434,"y":380.27507392726045,"color":"a"},{"x":356.61850599092844,"y":354.6703106638355,"color":"a"},{"x":381.60219701133474,"y":341.4077395956233,"color":"a"},{"x":375.6609301634428,"y":371.85779409080635,"color":"a"},{"x":394.153988603519,"y":347.79331591936693,"color":"a"},{"x":380.83271035188193,"y":306.4872195811691,"color":"a"},{"x":328.0589599965736,"y":315.5430857426486,"color":"a"},{"x":330.4136723599744,"y":371.51370775330827,"color":"a"},{"x":386.13466871423293,"y":335.7745309220181,"color":"a"},{"x":360.32687259485107,"y":324.792162840433,"color":"a"},{"x":347.49325537120984,"y":332.5031049047178,"color":"a"},{"x":329.1105015561375,"y":316.1566179926085,"color":"a"},{"x":414.54684359198563,"y":360.95842996497925,"color":"a"},{"x":427.907604783179,"y":328.313682705896,"color":"a"},{"x":425.84677895127163,"y":334.8156580723393,"color":"a"},{"x":388.2557115692061,"y":333.0170331481388,"color":"a"},{"x":392.27273263528485,"y":369.1477056799701,"color":"a"},{"x":372.962118703826,"y":381.0220843948833,"color":"a"},{"x":360.61709122047046,"y":375.7915379821045,"color":"a"},{"x":393.3010465183732,"y":381.5825665281624,"color":"a"},{"x":393.1676740713888,"y":388.7541884660872,"color":"a"},{"x":380.5542951663071,"y":312.4740783758673,"color":"a"},{"x":426.4828265471764,"y":397.25110295439083,"color":"a"},{"x":438.8203600436506,"y":406.3686892922209,"color":"a"},{"x":381.82405040171403,"y":361.44799465157047,"color":"a"},{"x":384.58054368188635,"y":389.29962355552937,"color":"a"}]
df = pd.DataFrame.from_dict(data, orient='columns')

plt.scatter(df["x"],df["y"])
plt.xlabel("Volumen 1/V (litros)")
plt.ylabel("Presión (atm)")
plt.title("Ley de Boyle P - 1/V")
m, b = np.polyfit(df["x"],df["y"],1)
plt.plot(df["x"],df["x"]*m + b, color = "red")
def f(x):
  y = m * x + b
  return y

print(f"La ecuacion de la Ley de boyle es: y = {m} * x + {b}")
# Out:
# La ecuacion de la Ley de boyle es: y = 0.9110923103728797 * x + 13.217799817123977

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = [{"x":20.86326353435765,"y":122.05777341427677,"color":"a"},{"x":-11.409999744150578,"y":89.35391052095571,"color":"a"},{"x":17.51320546671524,"y":114.7274381225389,"color":"a"},{"x":8.688840978161494,"y":91.04295254483765,"color":"a"},{"x":-2.7670770747987383,"y":112.96571214475767,"color":"a"},{"x":21.52230069898432,"y":102.4681779669042,"color":"a"},{"x":-23.516938529586277,"y":82.11350340005401,"color":"a"},{"x":16.420567384113323,"y":77.64310927981211,"color":"a"},{"x":31.557640290732742,"y":94.5415498918561,"color":"a"},{"x":23.660785916343496,"y":94.94523871814692,"color":"a"},{"x":51.993195865401766,"y":80.3341119252886,"color":"a"},{"x":-41.74563204886625,"y":141.9701486613517,"color":"a"},{"x":8.62365739504477,"y":86.79634634977538,"color":"a"},{"x":21.817280556958117,"y":144.246041052362,"color":"a"},{"x":41.764167040089816,"y":87.32214667685992,"color":"a"},{"x":40.05491567606245,"y":115.40231413876796,"color":"a"},{"x":88.35988393133512,"y":121.4370775473057,"color":"a"},{"x":22.128821509430956,"y":112.77965435081052,"color":"a"},{"x":22.187478970844687,"y":82.95802535075234,"color":"a"},{"x":33.41967872130678,"y":90.66512599450255,"color":"a"},{"x":40.84825863621747,"y":95.51257901765149,"color":"a"},{"x":37.216222704281144,"y":138.11019644772256,"color":"a"},{"x":28.178136789762558,"y":126.40769207414405,"color":"a"},{"x":62.08104339852804,"y":103.73904974572474,"color":"a"},{"x":41.81680745731996,"y":145.84356265469427,"color":"a"},{"x":31.507992604495154,"y":127.08344241422549,"color":"a"},{"x":32.37816982550556,"y":127.30581971450601,"color":"a"},{"x":78.84464620094909,"y":106.78144070253592,"color":"a"},{"x":85.76893923304371,"y":87.16083549091991,"color":"a"},{"x":61.89005877205962,"y":94.837242069284,"color":"a"},{"x":15.084468198776229,"y":100.14957982748837,"color":"a"},{"x":49.507252478432434,"y":136.98080857475907,"color":"a"},{"x":-4.17591197266708,"y":124.12080236654225,"color":"a"},{"x":78.4952031347842,"y":132.66820871526375,"color":"a"},{"x":34.6375507254133,"y":111.15510326854104,"color":"a"},{"x":75.37606362966457,"y":144.90805499659808,"color":"a"},{"x":4.93837461239373,"y":136.9093937605091,"color":"a"},{"x":42.0204984326977,"y":104.75891480815409,"color":"a"},{"x":60.48944375213206,"y":135.1339866477511,"color":"a"},{"x":-14.945330931971526,"y":142.8550552619999,"color":"a"},{"x":69.06716597535363,"y":151.33387361802562,"color":"a"},{"x":62.12773037684809,"y":122.22977636237249,"color":"a"},{"x":86.47885233306094,"y":143.27154813796648,"color":"a"},{"x":68.21014302166077,"y":122.81492420404948,"color":"a"},{"x":94.55987185433915,"y":150.85975884362244,"color":"a"},{"x":56.3116659660149,"y":161.06041459830476,"color":"a"},{"x":96.48183807557689,"y":142.51352632686132,"color":"a"},{"x":98.63580078707311,"y":130.41112736704855,"color":"a"},{"x":55.26384095042421,"y":103.65763359090545,"color":"a"},{"x":116.38840328339145,"y":114.47385622686795,"color":"a"},{"x":40.012378757697334,"y":147.80186610235575,"color":"a"},{"x":29.513836265318858,"y":155.77837619078667,"color":"a"},{"x":154.25628195881342,"y":163.57822774824882,"color":"a"},{"x":111.36761020529556,"y":204.55474353937132,"color":"a"},{"x":113.9883959090539,"y":178.52007284364436,"color":"a"},{"x":94.82091806622455,"y":175.68958094477375,"color":"a"},{"x":41.96150979574555,"y":167.1663383632814,"color":"a"},{"x":97.92711306209539,"y":178.32978476393635,"color":"a"},{"x":110.09375108140785,"y":174.85652496557697,"color":"a"},{"x":98.0070108706587,"y":172.2631416432156,"color":"a"},{"x":104.87469271931438,"y":195.92952319810138,"color":"a"},{"x":95.60190175134477,"y":178.98687435838917,"color":"a"},{"x":99.61184094918724,"y":197.3805308989019,"color":"a"},{"x":66.68404979330042,"y":154.19878339857667,"color":"a"},{"x":96.47333294500336,"y":161.74170466144687,"color":"a"},{"x":78.96163145192745,"y":150.92248936099224,"color":"a"},{"x":146.15232334110254,"y":214.73474699584818,"color":"a"},{"x":102.50038664738977,"y":194.29380329654362,"color":"a"},{"x":135.66592889230617,"y":194.0724686248236,"color":"a"},{"x":95.99038578089859,"y":182.04302270243215,"color":"a"},{"x":99.84275201423426,"y":176.79635777817384,"color":"a"},{"x":119.88043777465208,"y":147.96678011614347,"color":"a"},{"x":126.35754043409896,"y":186.8226345513736,"color":"a"},{"x":131.22200953414725,"y":212.01913669971947,"color":"a"},{"x":89.83813642180877,"y":94.4167871152178,"color":"a"},{"x":87.25504121544057,"y":197.18708929704854,"color":"a"},{"x":106.26383348881026,"y":186.86825102538916,"color":"a"},{"x":116.08165450985794,"y":151.35648984594525,"color":"a"},{"x":166.92995278442257,"y":173.73813915703448,"color":"a"},{"x":142.00532055386444,"y":156.78955230479488,"color":"a"},{"x":123.94456866420806,"y":189.1669870416278,"color":"a"},{"x":143.0105868788408,"y":152.661095924628,"color":"a"},{"x":176.67704882315388,"y":163.61413716509173,"color":"a"},{"x":141.48262482394222,"y":191.74904343146648,"color":"a"},{"x":159.8634456150049,"y":161.15200962324968,"color":"a"},{"x":85.58085831840211,"y":227.57528953287772,"color":"a"},{"x":117.71312445616958,"y":132.61025379410523,"color":"a"},{"x":140.31345897722085,"y":228.310841527854,"color":"a"},{"x":143.27839757463155,"y":160.48416597009748,"color":"a"},{"x":151.57212352272145,"y":181.4954694838449,"color":"a"},{"x":118.17968050552477,"y":199.14897141772207,"color":"a"},{"x":138.58568819928695,"y":203.27209962105007,"color":"a"},{"x":153.84915543563918,"y":205.1023805110579,"color":"a"},{"x":144.54480491509963,"y":229.10874459576354,"color":"a"},{"x":141.6494639948779,"y":176.3561165772167,"color":"a"},{"x":187.456541784848,"y":211.18633332707424,"color":"a"},{"x":131.78205319572484,"y":208.70277344830924,"color":"a"},{"x":121.14969620473423,"y":189.9075224458823,"color":"a"},{"x":142.70054080197067,"y":214.60418202973585,"color":"a"},{"x":169.77242470587962,"y":195.14779761101147,"color":"a"},{"x":214.68048936048564,"y":212.21388619004455,"color":"a"},{"x":204.1390767242569,"y":213.67078946365268,"color":"a"},{"x":193.0930808887887,"y":189.25483964156888,"color":"a"},{"x":172.89594687717968,"y":245.09308313998235,"color":"a"},{"x":121.77754845006862,"y":255.0157709418225,"color":"a"},{"x":132.24050263463903,"y":182.64541689394605,"color":"a"},{"x":118.37548249904276,"y":191.45705537848022,"color":"a"},{"x":151.95078646232054,"y":206.66290947871295,"color":"a"},{"x":156.27776622048606,"y":210.13961062875967,"color":"a"},{"x":163.54052158735632,"y":182.29793255958242,"color":"a"},{"x":186.32036765431636,"y":161.48794559352245,"color":"a"},{"x":198.97226809309245,"y":198.40820563157445,"color":"a"},{"x":122.70353046524488,"y":216.24204288527756,"color":"a"},{"x":199.80902985706604,"y":207.75862909341004,"color":"a"},{"x":216.27052995602247,"y":200.26719636397178,"color":"a"},{"x":177.67657989787858,"y":243.45629480944967,"color":"a"},{"x":193.45768554025128,"y":166.94131789053512,"color":"a"},{"x":154.16928979642807,"y":235.57014435484643,"color":"a"},{"x":164.01498788451286,"y":215.86246120609007,"color":"a"},{"x":180.18856902378505,"y":221.06544124381003,"color":"a"},{"x":196.7504238159367,"y":221.17144097377547,"color":"a"},{"x":201.97473798541554,"y":205.013954791463,"color":"a"},{"x":177.02227298542255,"y":235.21023976157932,"color":"a"},{"x":209.11886966354942,"y":194.120629641996,"color":"a"},{"x":170.93343490641513,"y":246.99012162654833,"color":"a"},{"x":185.3584693037414,"y":218.2379045381299,"color":"a"},{"x":205.94018698145788,"y":197.45335712115724,"color":"a"},{"x":275.4790982115379,"y":249.03777798956017,"color":"a"},{"x":142.09872017797392,"y":221.12201643062434,"color":"a"},{"x":215.11646244349154,"y":184.85606627050254,"color":"a"},{"x":218.35509211458023,"y":254.54432996219458,"color":"a"},{"x":229.1571614042308,"y":201.7744471294141,"color":"a"},{"x":213.89086603558934,"y":221.8962824285224,"color":"a"},{"x":229.99558830601188,"y":231.02578666966417,"color":"a"},{"x":212.74077621674707,"y":215.75654771018804,"color":"a"},{"x":201.0860126921609,"y":248.06583932514846,"color":"a"},{"x":225.03384306825882,"y":229.66043225238587,"color":"a"},{"x":216.0514536190524,"y":221.03309117272192,"color":"a"},{"x":244.97714327173918,"y":305.2006933685933,"color":"a"},{"x":224.10869110259904,"y":216.04316895391668,"color":"a"},{"x":183.82989965529083,"y":258.4466248134189,"color":"a"},{"x":208.11734766738962,"y":225.58396398135574,"color":"a"},{"x":222.44884910355097,"y":231.15390227325304,"color":"a"},{"x":213.2656832930795,"y":237.45661664784944,"color":"a"},{"x":278.2017396488845,"y":228.75630316772668,"color":"a"},{"x":224.75023616676896,"y":209.05701022671207,"color":"a"},{"x":212.5035324630632,"y":246.45770946217448,"color":"a"},{"x":221.21953825568002,"y":275.11127494326865,"color":"a"},{"x":299.274853687669,"y":248.94763832670338,"color":"a"},{"x":239.55125962976877,"y":267.2539375785084,"color":"a"},{"x":255.2682440907375,"y":266.7948705728623,"color":"a"},{"x":259.1781423919629,"y":311.30323747951354,"color":"a"},{"x":263.9392788558676,"y":250.4373343303633,"color":"a"},{"x":220.2761523660551,"y":292.8500237571659,"color":"a"},{"x":260.4977643088133,"y":239.60136339637614,"color":"a"},{"x":267.60199236384324,"y":239.19495891403255,"color":"a"},{"x":244.6268487583626,"y":256.9593241418403,"color":"a"},{"x":213.20560997277886,"y":224.16647497352903,"color":"a"},{"x":263.1592330306299,"y":237.79260489919045,"color":"a"},{"x":219.75300993586177,"y":294.5339899461583,"color":"a"},{"x":251.198570172276,"y":242.6788317528442,"color":"a"},{"x":241.97398258454277,"y":282.4346976962375,"color":"a"},{"x":192.2016315310652,"y":260.8596408349243,"color":"a"},{"x":246.68316381457805,"y":228.3408407777834,"color":"a"},{"x":237.70490263911077,"y":275.2336426883043,"color":"a"},{"x":275.0288259909874,"y":241.46626759600855,"color":"a"},{"x":303.0303437727925,"y":266.2528040068513,"color":"a"},{"x":201.3793994894544,"y":277.3895081295492,"color":"a"},{"x":248.4202309478198,"y":236.2244340663999,"color":"a"},{"x":243.64914583286287,"y":259.83574820586085,"color":"a"},{"x":289.593053321179,"y":276.71533186446436,"color":"a"},{"x":316.1746408782664,"y":238.11648677848387,"color":"a"},{"x":282.2150822132218,"y":279.9184607195216,"color":"a"},{"x":330.53048050961274,"y":267.7083368783717,"color":"a"},{"x":283.72151629305654,"y":275.35694833294326,"color":"a"},{"x":269.5611268974267,"y":252.84638665933576,"color":"a"},{"x":264.2726702383046,"y":295.23038233530644,"color":"a"},{"x":280.45123957313416,"y":271.26491647575864,"color":"a"},{"x":265.04724846239316,"y":308.6038095083268,"color":"a"},{"x":230.57204955712234,"y":278.4832640483552,"color":"a"},{"x":271.6504206758478,"y":254.92917822817918,"color":"a"},{"x":252.74135101814346,"y":279.98821157922384,"color":"a"},{"x":276.9482216619145,"y":305.8087594107686,"color":"a"},{"x":306.51011287075494,"y":279.8797187691283,"color":"a"},{"x":279.4973685909467,"y":289.97441287185893,"color":"a"},{"x":289.7817302000933,"y":296.7896975925394,"color":"a"},{"x":242.6837918227329,"y":284.0138804165485,"color":"a"},{"x":336.9226526975444,"y":296.59020357737097,"color":"a"},{"x":296.60461117506435,"y":248.59215343674094,"color":"a"},{"x":330.4486038563386,"y":284.0321337784804,"color":"a"},{"x":266.9172782912464,"y":281.5088538257898,"color":"a"},{"x":335.0929896703722,"y":318.22357404032033,"color":"a"},{"x":309.3506803478757,"y":290.7115921890227,"color":"a"},{"x":279.94322940233866,"y":292.3989568644131,"color":"a"},{"x":283.07354605318136,"y":315.871854546061,"color":"a"},{"x":321.0784393108018,"y":297.56314085554607,"color":"a"},{"x":324.6554053195528,"y":310.787740608381,"color":"a"},{"x":307.9654702043916,"y":265.926983451317,"color":"a"},{"x":335.5222119642379,"y":282.0505531799629,"color":"a"},{"x":317.1251826963416,"y":299.81140216446823,"color":"a"},{"x":286.50732647919375,"y":294.535341974254,"color":"a"},{"x":313.46752388482406,"y":269.9007165358721,"color":"a"},{"x":341.49213100285937,"y":281.90258843476147,"color":"a"},{"x":336.79830485148983,"y":298.9328699139747,"color":"a"},{"x":321.0298424365746,"y":272.07485826551545,"color":"a"},{"x":329.9199577033178,"y":298.73374848611,"color":"a"},{"x":348.5368398767069,"y":304.81677556736804,"color":"a"},{"x":313.59014247323023,"y":302.78009995308184,"color":"a"},{"x":328.357199147542,"y":318.441689041842,"color":"a"},{"x":298.74363444496765,"y":267.9276422633053,"color":"a"},{"x":383.5770725211605,"y":304.51383735428055,"color":"a"},{"x":317.88159213011915,"y":305.50490127743774,"color":"a"},{"x":317.4844943835766,"y":294.5592667402591,"color":"a"},{"x":316.3779572468052,"y":269.61079230414566,"color":"a"},{"x":332.67802547664627,"y":298.9280031429656,"color":"a"},{"x":337.8320445078523,"y":326.82136832691435,"color":"a"},{"x":364.6156795381223,"y":318.74615428505626,"color":"a"},{"x":338.7005848125234,"y":274.37435666167363,"color":"a"},{"x":331.78981971833514,"y":282.37752922668346,"color":"a"},{"x":327.9826427587155,"y":301.0683028093283,"color":"a"},{"x":331.9137522666841,"y":253.1479573048178,"color":"a"},{"x":334.0494120768464,"y":319.4488826251327,"color":"a"},{"x":320.17999785595975,"y":366.9860261941951,"color":"a"},{"x":341.5345004758349,"y":307.8820524079945,"color":"a"},{"x":317.3232649146357,"y":324.18949683563704,"color":"a"},{"x":326.66845502146987,"y":307.8569743332207,"color":"a"},{"x":329.7740027159818,"y":285.43421922424557,"color":"a"},{"x":325.7726934876179,"y":322.1885421512328,"color":"a"},{"x":325.7692250125738,"y":309.36691261458714,"color":"a"},{"x":343.1476478414181,"y":343.05144705767646,"color":"a"},{"x":339.0661964701971,"y":293.48226977706304,"color":"a"},{"x":342.13845049063036,"y":293.1074678880243,"color":"a"},{"x":352.13840396343807,"y":358.54154124482045,"color":"a"},{"x":372.5883920263204,"y":322.0991753294237,"color":"a"},{"x":362.9953254128707,"y":318.8323086691096,"color":"a"},{"x":320.3634545307735,"y":318.04502712334227,"color":"a"},{"x":335.5686437877482,"y":287.0184929012821,"color":"a"},{"x":371.5740097632198,"y":337.0513399855285,"color":"a"},{"x":398.8058092481957,"y":317.3626083709396,"color":"a"},{"x":347.31657883151735,"y":320.1427139427616,"color":"a"},{"x":377.48687449945936,"y":299.3811912023175,"color":"a"},{"x":355.61427014288597,"y":370.48437350194496,"color":"a"},{"x":374.47254330467354,"y":338.18585206147685,"color":"a"},{"x":356.73773474638995,"y":367.49720943717574,"color":"a"},{"x":291.8901423177,"y":319.90025474620796,"color":"a"},{"x":392.92544458924016,"y":292.88185355672124,"color":"a"},{"x":412.07962199327477,"y":333.44010016692266,"color":"a"},{"x":368.6706240323221,"y":311.36356605042033,"color":"a"},{"x":410.4978365932132,"y":271.61130710331975,"color":"a"},{"x":382.37589467822625,"y":328.3535043054891,"color":"a"},{"x":390.30784311251875,"y":347.7774388801523,"color":"a"},{"x":388.0517807265484,"y":309.1545983517702,"color":"a"},{"x":352.1550877072278,"y":332.4215515979606,"color":"a"},{"x":369.3626553927946,"y":349.57805103305594,"color":"a"},{"x":392.2455186934536,"y":383.5156860995736,"color":"a"},{"x":400.90891299835533,"y":384.06607157549195,"color":"a"},{"x":416.0328040302042,"y":299.80572037083186,"color":"a"},{"x":422.22864414925107,"y":331.6437450920449,"color":"a"},{"x":370.82635003128917,"y":329.58197176840696,"color":"a"},{"x":441.9863101492982,"y":376.34031388557946,"color":"a"},{"x":406.2140432532407,"y":314.58490060787983,"color":"a"},{"x":381.05657417146654,"y":357.117068172934,"color":"a"},{"x":406.36621734662623,"y":316.7649872096908,"color":"a"},{"x":391.325622442341,"y":330.0163269882673,"color":"a"},{"x":402.22664936183617,"y":364.45122539197575,"color":"a"},{"x":428.56854950251005,"y":304.91896943023426,"color":"a"},{"x":385.3751551160826,"y":335.66781133157264,"color":"a"},{"x":408.8441661423517,"y":384.1857080568594,"color":"a"},{"x":433.7998385493661,"y":326.56345735201626,"color":"a"},{"x":399.98867044585654,"y":366.09783810550687,"color":"a"},{"x":420.012147585885,"y":313.05979838682526,"color":"a"},{"x":421.0106490765712,"y":380.6486483311927,"color":"a"},{"x":421.2373880864008,"y":380.6647093943889,"color":"a"},{"x":410.18190004203205,"y":334.7031883085501,"color":"a"},{"x":393.89676353883675,"y":341.5070069002617,"color":"a"},{"x":427.1124059104403,"y":403.34982308176063,"color":"a"},{"x":457.65200641828784,"y":382.6593398924742,"color":"a"},{"x":422.30030842537167,"y":343.6792337439999,"color":"a"},{"x":391.7794745447737,"y":346.6220069913836,"color":"a"},{"x":443.0543494121186,"y":370.3459566478615,"color":"a"},{"x":425.48085946404376,"y":340.9505536505873,"color":"a"},{"x":435.90418969253824,"y":347.06857232512465,"color":"a"},{"x":418.9399850216426,"y":379.51620324603823,"color":"a"},{"x":465.1451786271914,"y":429.39043275387803,"color":"a"},{"x":463.80906082509705,"y":380.3594892395804,"color":"a"},{"x":409.93906284225216,"y":358.61802289838545,"color":"a"},{"x":423.2302885548372,"y":391.40901854360044,"color":"a"},{"x":449.00501805248615,"y":375.58702546573807,"color":"a"},{"x":440.5510203440083,"y":341.4636640603044,"color":"a"},{"x":437.08306107641147,"y":402.48041924835206,"color":"a"},{"x":407.14732602246943,"y":333.30169688973945,"color":"a"},{"x":467.17759562225615,"y":343.67170756616747,"color":"a"},{"x":442.3906964975081,"y":365.8927365101613,"color":"a"},{"x":464.97969498723336,"y":379.6594268753504,"color":"a"},{"x":440.9024172728792,"y":408.50900425932093,"color":"a"},{"x":397.6371344060629,"y":408.52045657468534,"color":"a"},{"x":426.50004270109514,"y":376.13572951767674,"color":"a"},{"x":461.1694485060952,"y":402.2719450433856,"color":"a"},{"x":428.9397983283021,"y":355.2032581154197,"color":"a"},{"x":439.0397403175132,"y":341.98806558889385,"color":"a"},{"x":479.824158264096,"y":348.25059161370706,"color":"a"},{"x":472.29600824121127,"y":335.34400381214164,"color":"a"},{"x":464.0989088176197,"y":387.2956071446031,"color":"a"},{"x":426.3867297340162,"y":381.6329621175285,"color":"a"},{"x":469.4107986401222,"y":445.4528610399647,"color":"a"},{"x":455.41714004431253,"y":337.8206743080812,"color":"a"},{"x":436.9102794335129,"y":382.39888044864426,"color":"a"},{"x":468.06535982051054,"y":376.9253047645954,"color":"a"},{"x":443.7247928243447,"y":406.6025513595573,"color":"a"},{"x":440.46705859318314,"y":428.83219562338184,"color":"a"},{"x":474.69248920044924,"y":415.94267163827965,"color":"a"},{"x":470.6987444532953,"y":366.7227123581722,"color":"a"},{"x":459.59316030573666,"y":385.0121829047982,"color":"a"},{"x":482.442316933075,"y":366.39283033567926,"color":"a"},{"x":451.49888629465363,"y":368.5773451688825,"color":"a"},{"x":485.4845897620735,"y":432.7082790745919,"color":"a"},{"x":447.75461290257755,"y":375.93817521729517,"color":"a"},{"x":484.9110584653212,"y":395.61306571908153,"color":"a"},{"x":434.01046131708546,"y":401.7729730853019,"color":"a"},{"x":436.6309518771919,"y":392.5586327520931,"color":"a"},{"x":446.01832187923634,"y":417.11948076845226,"color":"a"},{"x":469.8166995431956,"y":376.64465251842637,"color":"a"},{"x":504.89697720170864,"y":353.11307387086407,"color":"a"},{"x":466.0017439369628,"y":344.2345337556743,"color":"a"},{"x":418.0912161973817,"y":378.142788071328,"color":"a"},{"x":427.73044943088325,"y":395.638857720752,"color":"a"},{"x":444.94866138611536,"y":433.5594710271855,"color":"a"},{"x":450.43554677571564,"y":369.8956069477557,"color":"a"},{"x":436.1617392960063,"y":448.0962271083353,"color":"a"},{"x":480.77016023340974,"y":401.15634348677776,"color":"a"},{"x":473.77708533872425,"y":393.60359055385794,"color":"a"},{"x":538.1328756790771,"y":390.0130528528781,"color":"a"},{"x":446.7149436212902,"y":364.32241962757,"color":"a"},{"x":480.4077981865989,"y":401.0670136450431,"color":"a"},{"x":455.36951501242305,"y":383.98202528853363,"color":"a"},{"x":490.8950763681263,"y":406.32307467878854,"color":"a"},{"x":509.16351156776994,"y":366.4715080793611,"color":"a"},{"x":460.1051024159052,"y":313.7514461255508,"color":"a"},{"x":455.61463423956536,"y":448.93606752307795,"color":"a"},{"x":482.9164436074074,"y":387.5756773447969,"color":"a"},{"x":510.25819905002004,"y":412.88978224127754,"color":"a"},{"x":500.41975316221675,"y":298.9544354381879,"color":"a"},{"x":474.34901209954654,"y":447.37240331175127,"color":"a"},{"x":458.10163940344415,"y":383.89403954029933,"color":"a"},{"x":495.4314520705599,"y":400.187260339404,"color":"a"},{"x":473.9902386476419,"y":378.011800355979,"color":"a"},{"x":446.7174070389363,"y":390.0195433144412,"color":"a"},{"x":499.9108960856875,"y":441.57378287821984,"color":"a"},{"x":482.61998057155614,"y":385.65113715146015,"color":"a"},{"x":504.0937758525569,"y":419.75616481988254,"color":"a"},{"x":457.6432000231016,"y":417.8477737689291,"color":"a"},{"x":462.6192878241328,"y":447.5085820504628,"color":"a"},{"x":493.7861072469471,"y":399.94750471455666,"color":"a"},{"x":522.0332289576027,"y":410.0028446756847,"color":"a"},{"x":534.9860026680755,"y":448.1989778425617,"color":"a"},{"x":509.5048242103393,"y":467.9307387378965,"color":"a"},{"x":507.8742032334676,"y":428.97816415312803,"color":"a"},{"x":525.8271815569572,"y":420.51667904212553,"color":"a"},{"x":511.991428512714,"y":429.60513686111733,"color":"a"},{"x":517.8002671053587,"y":374.201569641182,"color":"a"},{"x":509.366141398862,"y":379.7728646569068,"color":"a"},{"x":488.56655397806827,"y":395.08493548759895,"color":"a"},{"x":555.5218425577664,"y":407.24616315300267,"color":"a"},{"x":511.2515811008824,"y":419.94726274099406,"color":"a"},{"x":545.9460639232743,"y":478.6970302853486,"color":"a"},{"x":491.77770178150627,"y":482.8285890971944,"color":"a"},{"x":499.32651488530206,"y":451.8358081697897,"color":"a"},{"x":557.3493993085838,"y":394.23215315323523,"color":"a"},{"x":514.968638821515,"y":451.1542880313631,"color":"a"},{"x":539.7633242877275,"y":435.3445847760597,"color":"a"},{"x":511.61440651222756,"y":407.4612828298873,"color":"a"},{"x":527.8309775733965,"y":411.70522648028214,"color":"a"},{"x":534.780672599264,"y":439.25159549940486,"color":"a"},{"x":509.5723285537088,"y":406.7186937481107,"color":"a"},{"x":519.7937974534814,"y":445.24725397465573,"color":"a"},{"x":506.57322018509853,"y":419.8092632049847,"color":"a"},{"x":582.1787732520078,"y":414.63043848153256,"color":"a"},{"x":484.0962790464663,"y":406.60382721845536,"color":"a"},{"x":529.8858260288256,"y":419.921628755763,"color":"a"},{"x":558.4501562406547,"y":398.9424873892863,"color":"a"},{"x":527.1910969548524,"y":432.16526113359777,"color":"a"},{"x":523.0122250735426,"y":425.3193551066838,"color":"a"},{"x":548.5642915902341,"y":452.09229051872023,"color":"a"},{"x":500.0460564609454,"y":429.94787445634887,"color":"a"},{"x":552.4347595681097,"y":416.86007075895316,"color":"a"},{"x":549.8242532177483,"y":448.5673034055749,"color":"a"},{"x":514.7174368723138,"y":467.51608459413285,"color":"a"},{"x":551.7576583605679,"y":423.30814574588857,"color":"a"},{"x":563.1744192033875,"y":432.05026976199576,"color":"a"},{"x":521.5268171847582,"y":460.7322320992741,"color":"a"},{"x":597.0710356893757,"y":427.4076527483785,"color":"a"},{"x":588.5358604053089,"y":435.78938499374686,"color":"a"},{"x":504.9105478150907,"y":415.20690528648333,"color":"a"},{"x":537.8956680818397,"y":497.8658913437524,"color":"a"},{"x":495.646332883147,"y":420.85124638132095,"color":"a"},{"x":526.6142756446976,"y":450.18213637710284,"color":"a"},{"x":542.2641872089436,"y":439.8817570953619,"color":"a"},{"x":519.0601664901167,"y":402.85934354510425,"color":"a"},{"x":524.4905541908316,"y":447.9433878737982,"color":"a"},{"x":569.5088170938119,"y":415.0729614794292,"color":"a"},{"x":552.0001493693193,"y":422.1747714670676,"color":"a"},{"x":567.3773117902751,"y":450.6336438722423,"color":"a"},{"x":520.3378644558722,"y":423.84853408181516,"color":"a"},{"x":543.1394772707524,"y":420.6525806307186,"color":"a"},{"x":588.064878056421,"y":432.512034109496,"color":"a"},{"x":563.9116877674269,"y":450.68066881743044,"color":"a"},{"x":564.5472666513432,"y":459.3543106549939,"color":"a"},{"x":571.3748442501604,"y":463.4891904211837,"color":"a"},{"x":563.10609690736,"y":517.6120054756401,"color":"a"},{"x":562.4672185675838,"y":482.9755357578333,"color":"a"},{"x":540.8671086536117,"y":483.29237848830115,"color":"a"},{"x":564.9598786021115,"y":421.903718443393,"color":"a"},{"x":539.135582465793,"y":470.32207334309726,"color":"a"},{"x":624.2616434993969,"y":435.5586944165962,"color":"a"},{"x":534.913290360691,"y":486.88858742027224,"color":"a"},{"x":578.6386099761947,"y":512.9019385167978,"color":"a"},{"x":547.6836662029542,"y":428.050165902503,"color":"a"},{"x":595.6494898241681,"y":474.95322337055904,"color":"a"},{"x":580.6899404350792,"y":446.0509511663882,"color":"a"},{"x":597.0108678338693,"y":486.00434070115045,"color":"a"},{"x":543.542594219635,"y":445.9852699003232,"color":"a"},{"x":576.2133160975374,"y":471.4738274526046,"color":"a"},{"x":550.323587843741,"y":447.93092863579426,"color":"a"},{"x":576.0007980045326,"y":468.68028134000116,"color":"a"},{"x":612.5507573167584,"y":473.8856545901961,"color":"a"},{"x":579.370155552655,"y":463.91186746624214,"color":"a"},{"x":621.7497353853552,"y":443.0006412720937,"color":"a"},{"x":575.1965085247938,"y":481.993032014273,"color":"a"},{"x":603.2717401434107,"y":451.829311373538,"color":"a"},{"x":618.2963177526678,"y":489.83639397307417,"color":"a"},{"x":520.2965169145468,"y":449.02565054280524,"color":"a"},{"x":528.0189906882266,"y":502.9249449553582,"color":"a"},{"x":629.7897217736494,"y":453.5508698463977,"color":"a"},{"x":565.1010273684229,"y":448.1933144096816,"color":"a"},{"x":555.4818894734315,"y":423.8964356768553,"color":"a"},{"x":618.6343981563203,"y":445.37364061690704,"color":"a"},{"x":590.0318379762682,"y":481.3604948315741,"color":"a"},{"x":604.693150408532,"y":465.1558261059951,"color":"a"},{"x":597.9339369056192,"y":496.04081349488996,"color":"a"},{"x":581.9627772414754,"y":460.51286067062784,"color":"a"},{"x":622.1674534043284,"y":472.09444469986516,"color":"a"},{"x":553.4556962435023,"y":478.45790690461035,"color":"a"},{"x":630.7032457308936,"y":503.66125463213695,"color":"a"},{"x":593.0505742889028,"y":478.94296898926683,"color":"a"},{"x":597.5469021648679,"y":462.6723560092581,"color":"a"},{"x":620.1635438089954,"y":492.07113047854426,"color":"a"},{"x":593.4665333797825,"y":456.55958398606646,"color":"a"},{"x":642.1557393537524,"y":440.550440484018,"color":"a"},{"x":648.9805521276919,"y":470.6012789353991,"color":"a"},{"x":614.4671010868556,"y":492.80653282775427,"color":"a"},{"x":669.589285894678,"y":491.3736492523561,"color":"a"},{"x":619.3034438732892,"y":448.33507724991887,"color":"a"},{"x":652.0951024742064,"y":461.04110403606995,"color":"a"},{"x":598.4299490156516,"y":493.55076320227175,"color":"a"},{"x":608.1452625788686,"y":444.97106243824817,"color":"a"},{"x":590.0300858031933,"y":471.52338379662683,"color":"a"},{"x":607.699776437515,"y":484.04639203935443,"color":"a"},{"x":666.8018358299423,"y":433.2434163427315,"color":"a"},{"x":587.3525037186922,"y":504.27368060733613,"color":"a"},{"x":621.7486074183882,"y":484.7921300492538,"color":"a"},{"x":626.1959271672163,"y":458.3357057786139,"color":"a"},{"x":605.9143198755435,"y":495.43882760088013,"color":"a"},{"x":650.574468336164,"y":476.5427661404236,"color":"a"},{"x":622.5158861937296,"y":504.00920158348396,"color":"a"},{"x":636.1963173223389,"y":487.7929319886082,"color":"a"},{"x":592.1758608510811,"y":495.65866146584307,"color":"a"}]
df = pd.DataFrame.from_dict(data, orient='columns')
plt.scatter(df["x"],df["y"])
plt.xlabel("Temperatura (K)")
plt.ylabel("Volumen (l)")
plt.title("Ley de Charles")
m, b = np.polyfit(df["x"],df["y"],1)
plt.plot(df["x"],df["x"]*m + b, color = "red")
def f(x):
  y = m * x + b
  return y

print(f"La ecuacion de la Ley de Charles es: y = {m} * x + {b}")
# Out:
# La ecuacion de la Ley de Charles es: y = 0.610993869075669 * x + 102.97451986604078

# %%
data = [{"x":6.534395524449485,"y":-32.02923335019295,"color":"a"},{"x":20.167942219054893,"y":-10.763984502635424,"color":"a"},{"x":-16.92401760664455,"y":4.053358025569821,"color":"a"},{"x":-21.775456293624845,"y":27.060235941653616,"color":"a"},{"x":45.01455538809877,"y":25.728838939035427,"color":"a"},{"x":53.95866439598418,"y":-3.8865010934516704,"color":"a"},{"x":9.890347835478304,"y":-1.9271235346650997,"color":"a"},{"x":-6.216394640538962,"y":14.851055595603441,"color":"a"},{"x":14.44317854544105,"y":18.976162554274026,"color":"a"},{"x":19.31150018521281,"y":-17.694160406818924,"color":"a"},{"x":36.32087533657632,"y":-4.097286409860487,"color":"a"},{"x":50.13241439029906,"y":46.64183648031553,"color":"a"},{"x":20.40124175467769,"y":62.611424269031886,"color":"a"},{"x":37.73581481039879,"y":29.33609640106107,"color":"a"},{"x":55.85475293858369,"y":53.543563722585816,"color":"a"},{"x":33.33764091855951,"y":10.435396032848473,"color":"a"},{"x":60.988151622838615,"y":63.58596204170021,"color":"a"},{"x":34.98494423970719,"y":48.79004426932613,"color":"a"},{"x":-4.493435161820123,"y":19.414094063456844,"color":"a"},{"x":51.9148608794846,"y":9.126674479713074,"color":"a"},{"x":28.11036250871732,"y":23.10225231089595,"color":"a"},{"x":23.137017013518744,"y":48.365262314529446,"color":"a"},{"x":-7.662762186558638,"y":83.58829384246837,"color":"a"},{"x":114.72687184621368,"y":27.689146928227046,"color":"a"},{"x":42.83219283781497,"y":54.32684004366553,"color":"a"},{"x":25.805360425079666,"y":43.666152197834265,"color":"a"},{"x":58.69379438298276,"y":37.19680849442824,"color":"a"},{"x":5.193075767719357,"y":57.0827191838124,"color":"a"},{"x":94.25447990678795,"y":28.146151022010372,"color":"a"},{"x":63.5703122336107,"y":42.075352493104276,"color":"a"},{"x":110.63427032860602,"y":40.05531051700103,"color":"a"},{"x":128.8642149374807,"y":53.701112183095574,"color":"a"},{"x":88.90025499947023,"y":56.91436208829663,"color":"a"},{"x":45.45467892144522,"y":73.40288321038446,"color":"a"},{"x":77.61648264297068,"y":117.17103134032646,"color":"a"},{"x":107.24141342664637,"y":104.50371159821646,"color":"a"},{"x":55.75706776830589,"y":67.45395865416032,"color":"a"},{"x":94.18987255330065,"y":38.10019396071124,"color":"a"},{"x":89.00220578673536,"y":49.70948808597092,"color":"a"},{"x":70.28272903775222,"y":81.8340430091464,"color":"a"},{"x":77.86284204549194,"y":69.45140780899612,"color":"a"},{"x":79.2734368109027,"y":59.37335245134136,"color":"a"},{"x":104.25202435435747,"y":81.7926196268802,"color":"a"},{"x":135.39203843823756,"y":45.33464897913399,"color":"a"},{"x":63.194383786018804,"y":83.01543972740762,"color":"a"},{"x":140.08683603865592,"y":38.755269032060255,"color":"a"},{"x":102.95054118667228,"y":95.70255463508619,"color":"a"},{"x":148.8974905978144,"y":107.4149248167887,"color":"a"},{"x":69.02118255822448,"y":72.55103941659087,"color":"a"},{"x":139.28781175016582,"y":17.616320676495093,"color":"a"},{"x":73.8168822360449,"y":84.65985232679787,"color":"a"},{"x":91.9751217073556,"y":116.17748169005785,"color":"a"},{"x":77.3517524645039,"y":75.54480888454026,"color":"a"},{"x":102.8018389537276,"y":97.44962754668728,"color":"a"},{"x":150.13237591075406,"y":65.90548734594432,"color":"a"},{"x":125.81658994251995,"y":151.0217256423574,"color":"a"},{"x":102.07816361190199,"y":50.22975841201736,"color":"a"},{"x":88.68361071388128,"y":75.1360524498844,"color":"a"},{"x":134.34710462800092,"y":75.6280925972759,"color":"a"},{"x":122.3195773072505,"y":72.47411703212725,"color":"a"},{"x":171.8304708887967,"y":97.23162475025157,"color":"a"},{"x":108.6850555710904,"y":140.71697780723696,"color":"a"},{"x":116.30442720563595,"y":48.142835657146406,"color":"a"},{"x":144.138298149011,"y":109.02264146666812,"color":"a"},{"x":146.3308868249953,"y":53.204143288508476,"color":"a"},{"x":138.13623492415124,"y":103.84097921336377,"color":"a"},{"x":128.32429861225447,"y":119.58119635212563,"color":"a"},{"x":118.63395984122485,"y":113.95142062357814,"color":"a"},{"x":155.88357809426108,"y":101.34870923256665,"color":"a"},{"x":134.60576296284242,"y":96.0385816528883,"color":"a"},{"x":137.0921308271715,"y":91.87449055137591,"color":"a"},{"x":176.6237683338669,"y":100.63087698527283,"color":"a"},{"x":142.60948976869435,"y":125.56289192196334,"color":"a"},{"x":139.28918936483,"y":93.53800565272587,"color":"a"},{"x":165.00799746110368,"y":112.57054563950521,"color":"a"},{"x":108.27060630422031,"y":122.89463484769357,"color":"a"},{"x":176.19664317065542,"y":58.758378842056175,"color":"a"},{"x":150.48374940739296,"y":124.94476840432174,"color":"a"},{"x":131.96075144657482,"y":174.29531372236897,"color":"a"},{"x":193.76466847045504,"y":103.11972539130528,"color":"a"},{"x":167.57658243997793,"y":109.58426010856721,"color":"a"},{"x":170.6918665650162,"y":92.27679159101143,"color":"a"},{"x":167.8451138229912,"y":84.75432589586279,"color":"a"},{"x":104.95170644821626,"y":79.63592370960271,"color":"a"},{"x":134.09569803675797,"y":138.6929602111694,"color":"a"},{"x":128.083687068131,"y":103.29388525904324,"color":"a"},{"x":163.5206283356393,"y":150.01527113912414,"color":"a"},{"x":150.1694798442704,"y":105.64443538838913,"color":"a"},{"x":177.45002502279533,"y":171.37706746806998,"color":"a"},{"x":189.22981659042483,"y":158.1266612843757,"color":"a"},{"x":193.2833999323563,"y":124.17162078977765,"color":"a"},{"x":183.6191277853968,"y":137.77051493528546,"color":"a"},{"x":165.8646878293772,"y":114.24406575309985,"color":"a"},{"x":218.19476337553598,"y":142.09768060122252,"color":"a"},{"x":177.57126374689435,"y":103.74529808494736,"color":"a"},{"x":152.48641261647177,"y":130.11466690500157,"color":"a"},{"x":181.06867363126085,"y":140.85586375603617,"color":"a"},{"x":153.148191208931,"y":60.723341945898994,"color":"a"},{"x":217.0831891825351,"y":118.90333874336943,"color":"a"},{"x":189.80720591490422,"y":117.39153809681824,"color":"a"},{"x":210.17169513183447,"y":120.31876677272089,"color":"a"},{"x":234.2079547369122,"y":152.1487223033397,"color":"a"},{"x":136.1242643406381,"y":135.45335708130267,"color":"a"},{"x":143.31835402427686,"y":158.32218268112752,"color":"a"},{"x":203.50558158512902,"y":187.2394662341938,"color":"a"},{"x":183.5335802589915,"y":91.38819935098962,"color":"a"},{"x":194.60729915721328,"y":199.6655306251364,"color":"a"},{"x":174.49948745214795,"y":179.0745939181641,"color":"a"},{"x":185.836286298148,"y":143.88275977345324,"color":"a"},{"x":213.2266927985671,"y":172.00339663833068,"color":"a"},{"x":212.0332322916208,"y":145.1164076613416,"color":"a"},{"x":215.01701605913325,"y":151.25434383099116,"color":"a"},{"x":214.94740862892593,"y":138.81590244041496,"color":"a"},{"x":192.3598866799829,"y":169.96255127926946,"color":"a"},{"x":210.209488159495,"y":176.7008316874049,"color":"a"},{"x":201.02007382695749,"y":167.5107466565234,"color":"a"},{"x":255.3391191984152,"y":172.11265546822,"color":"a"},{"x":218.492965597841,"y":191.06150504389382,"color":"a"},{"x":261.89422353199075,"y":145.39758725020437,"color":"a"},{"x":223.75935565015914,"y":139.83622273672978,"color":"a"},{"x":197.16240042438162,"y":202.36633770050827,"color":"a"},{"x":252.51539684141306,"y":144.4392451993101,"color":"a"},{"x":247.6977547556623,"y":148.84212356488888,"color":"a"},{"x":253.17665305417282,"y":202.02128064232733,"color":"a"},{"x":284.9483170701939,"y":176.0031005549572,"color":"a"},{"x":244.50287914196204,"y":215.2738848451454,"color":"a"},{"x":187.9143788686851,"y":193.2345880411171,"color":"a"},{"x":227.0544945672955,"y":163.44117844256937,"color":"a"},{"x":233.1055950626293,"y":169.33961065109082,"color":"a"},{"x":184.66965802503688,"y":161.54843410539735,"color":"a"},{"x":200.47292992256666,"y":238.11206530727958,"color":"a"},{"x":269.2087923054783,"y":175.45108164218186,"color":"a"},{"x":250.54794700278214,"y":176.5545001159602,"color":"a"},{"x":264.32293100334124,"y":210.18386980216985,"color":"a"},{"x":241.9371848673843,"y":175.61234958971494,"color":"a"},{"x":265.83030149984336,"y":142.31008623647148,"color":"a"},{"x":258.61542456881523,"y":189.88034379152015,"color":"a"},{"x":218.0115672796303,"y":219.8615417801119,"color":"a"},{"x":242.54276542680708,"y":180.84819877504464,"color":"a"},{"x":238.12102729645179,"y":214.56529609970204,"color":"a"},{"x":221.69307820686626,"y":179.86083489142197,"color":"a"},{"x":268.37834779051434,"y":169.80416394661773,"color":"a"},{"x":275.02235186303255,"y":199.27420496240404,"color":"a"},{"x":239.3188616590371,"y":219.61608182185336,"color":"a"},{"x":274.84890157185265,"y":180.27215214698163,"color":"a"},{"x":263.8765430989744,"y":192.13500140540515,"color":"a"},{"x":215.7024090871023,"y":243.1580503298589,"color":"a"},{"x":246.3759638182772,"y":219.53191475820256,"color":"a"},{"x":230.39320423316587,"y":204.23977565353954,"color":"a"},{"x":256.8711233531753,"y":178.55492586200967,"color":"a"},{"x":311.53565561178135,"y":239.63800440657388,"color":"a"},{"x":286.8768099457705,"y":220.9662211458916,"color":"a"},{"x":242.74527622935165,"y":180.62604333925418,"color":"a"},{"x":254.4388823392984,"y":188.10855426644844,"color":"a"},{"x":287.028225440668,"y":214.0341214772293,"color":"a"},{"x":276.1905202788561,"y":249.0005642627366,"color":"a"},{"x":318.7762746086309,"y":246.85379753886613,"color":"a"},{"x":271.14359773699636,"y":231.57458126041405,"color":"a"},{"x":273.86339342562263,"y":223.67240919262406,"color":"a"},{"x":270.9030818419282,"y":223.67363195349088,"color":"a"},{"x":260.955656757994,"y":237.49536248975517,"color":"a"},{"x":364.49029652953124,"y":267.5206244143738,"color":"a"},{"x":332.6499828605692,"y":259.54849509936537,"color":"a"},{"x":284.30273818716336,"y":228.11038907738163,"color":"a"},{"x":263.4980250191716,"y":197.67743060002243,"color":"a"},{"x":305.9997961399349,"y":257.0780930451657,"color":"a"},{"x":317.134792101257,"y":221.53510689277283,"color":"a"},{"x":313.8055399764523,"y":206.87379439050568,"color":"a"},{"x":275.3292078888606,"y":246.92039494282665,"color":"a"},{"x":309.73055919135487,"y":182.04883821961545,"color":"a"},{"x":312.4824133167936,"y":245.4656220687166,"color":"a"},{"x":259.1000488906988,"y":209.96982000950464,"color":"a"},{"x":306.84788332162805,"y":238.3210094484872,"color":"a"},{"x":291.6054193298038,"y":244.85056358104697,"color":"a"},{"x":357.95776359281814,"y":232.21100616579838,"color":"a"},{"x":337.3912799875419,"y":203.6828960512467,"color":"a"},{"x":282.32920463621195,"y":234.9144996738608,"color":"a"},{"x":329.4739661062592,"y":247.1347856496091,"color":"a"},{"x":301.3001146385649,"y":238.76404721004735,"color":"a"},{"x":354.61328253223394,"y":233.64168103914608,"color":"a"},{"x":339.09962107251846,"y":255.17100279400742,"color":"a"},{"x":363.6103230096142,"y":283.136122302854,"color":"a"},{"x":330.3955004215952,"y":274.3233726599049,"color":"a"},{"x":327.8185724911206,"y":265.4959661945182,"color":"a"},{"x":350.5123965058666,"y":273.10822571353617,"color":"a"},{"x":367.8289136573831,"y":289.3636653892104,"color":"a"},{"x":356.6897219545704,"y":247.95575380025787,"color":"a"},{"x":306.8988375849069,"y":266.56380939661693,"color":"a"},{"x":359.81052360366124,"y":270.1061567381119,"color":"a"},{"x":311.1775336751781,"y":255.5993048514952,"color":"a"},{"x":304.0822331432781,"y":257.4022411731284,"color":"a"},{"x":343.7038180388134,"y":280.43892599200205,"color":"a"},{"x":316.3079356083163,"y":315.865143151796,"color":"a"},{"x":362.1537460776291,"y":257.810339396093,"color":"a"},{"x":386.88595864669867,"y":218.83413123845935,"color":"a"},{"x":299.10783545693914,"y":241.6696462873888,"color":"a"},{"x":317.9797704763684,"y":265.65710139419843,"color":"a"},{"x":328.9506158197671,"y":297.1470564653814,"color":"a"},{"x":355.5096002074823,"y":258.7241629952348,"color":"a"},{"x":356.52564902571476,"y":256.19869342225354,"color":"a"},{"x":380.1435311622383,"y":272.1756749003353,"color":"a"},{"x":303.10228145714603,"y":296.5696412628957,"color":"a"},{"x":390.7537460904804,"y":255.0313740751277,"color":"a"},{"x":371.1516253172902,"y":275.46519556025197,"color":"a"},{"x":366.36960480957555,"y":228.5054253693516,"color":"a"},{"x":313.06368265963914,"y":277.51035724097164,"color":"a"},{"x":329.73488205954527,"y":280.59316253858685,"color":"a"},{"x":390.9848978196797,"y":295.6482221321918,"color":"a"},{"x":357.9292094980486,"y":262.25153453768735,"color":"a"},{"x":359.75173987140914,"y":280.3623919077701,"color":"a"},{"x":343.0352598589421,"y":294.56769881168225,"color":"a"},{"x":412.1363967452518,"y":309.5706522785184,"color":"a"},{"x":348.67335588634677,"y":233.41690214949995,"color":"a"},{"x":357.26957680536356,"y":270.3884791917006,"color":"a"},{"x":354.28559966243864,"y":284.80874572347574,"color":"a"},{"x":370.8764960286221,"y":281.3270176491777,"color":"a"},{"x":307.81058410171374,"y":285.6577052443593,"color":"a"},{"x":385.9402590966674,"y":274.719202995334,"color":"a"},{"x":386.3808591808625,"y":287.6163855755119,"color":"a"},{"x":349.01141433515886,"y":301.5570288509683,"color":"a"},{"x":364.81002377236683,"y":270.91475409962686,"color":"a"},{"x":399.6702977344079,"y":338.4621678803906,"color":"a"},{"x":392.0386337559194,"y":301.152007387287,"color":"a"},{"x":404.08165930851663,"y":252.29074392677984,"color":"a"},{"x":389.4974420603517,"y":278.74978308505973,"color":"a"},{"x":410.7047886945162,"y":273.3660407992379,"color":"a"},{"x":411.29365908720615,"y":294.9037482114802,"color":"a"},{"x":400.4225612919313,"y":284.21178307187625,"color":"a"},{"x":409.2868431963476,"y":299.496553422,"color":"a"},{"x":370.48037795634457,"y":286.60316627902574,"color":"a"},{"x":388.33116031139235,"y":332.3561333548237,"color":"a"},{"x":384.6422431527613,"y":306.96413959451974,"color":"a"},{"x":405.3041944448614,"y":292.07083500763395,"color":"a"},{"x":367.26866997026445,"y":282.1081887288149,"color":"a"},{"x":395.7848146418263,"y":278.61410518654066,"color":"a"},{"x":458.97500052266696,"y":327.24835404077874,"color":"a"},{"x":418.16429424426457,"y":327.62100472270623,"color":"a"},{"x":395.1620219900171,"y":324.63033519387875,"color":"a"},{"x":437.6903849006627,"y":303.2089090257014,"color":"a"},{"x":453.92576324553403,"y":286.75806252346035,"color":"a"},{"x":456.07112233052413,"y":354.97251833687653,"color":"a"},{"x":404.0889155032394,"y":359.07821572357443,"color":"a"},{"x":437.74368212371536,"y":313.2709311511086,"color":"a"},{"x":400.77531640164386,"y":367.98782372596384,"color":"a"},{"x":416.67377343668875,"y":340.6047458405868,"color":"a"},{"x":438.55322227378406,"y":384.33391306209097,"color":"a"},{"x":412.26632604089775,"y":337.02719539422515,"color":"a"},{"x":436.72352879291634,"y":359.2461771255741,"color":"a"},{"x":449.44347491407166,"y":262.14759477640587,"color":"a"},{"x":436.08417602583995,"y":361.4201338496963,"color":"a"},{"x":458.1054612778606,"y":284.4092770656913,"color":"a"},{"x":439.6791935151459,"y":363.1370706229247,"color":"a"},{"x":404.7857309880036,"y":305.05234201811163,"color":"a"},{"x":469.7055013478212,"y":279.17631771979654,"color":"a"},{"x":420.4223392991913,"y":319.59059338425084,"color":"a"},{"x":427.70977318033044,"y":363.00777025654145,"color":"a"},{"x":467.8379626131713,"y":353.80395367342544,"color":"a"},{"x":439.14795537711774,"y":325.74172705302914,"color":"a"},{"x":443.1496114142436,"y":358.56701746513636,"color":"a"},{"x":447.958734724532,"y":330.7189434013103,"color":"a"},{"x":462.41851126771866,"y":322.9017365528799,"color":"a"},{"x":497.7566910408226,"y":328.97802889083505,"color":"a"},{"x":397.31984202905943,"y":338.7172550597586,"color":"a"},{"x":465.4540553015879,"y":367.43563107178875,"color":"a"},{"x":449.8844659859781,"y":360.78816991612973,"color":"a"},{"x":473.4453828077689,"y":339.37741224988815,"color":"a"},{"x":454.81564552128276,"y":430.0718934347457,"color":"a"},{"x":463.6785854615598,"y":321.8737476883068,"color":"a"},{"x":489.1778204355472,"y":418.0877185994136,"color":"a"},{"x":435.2390168944165,"y":357.272830949739,"color":"a"},{"x":524.0229920780047,"y":330.4370372157174,"color":"a"},{"x":473.7925976791517,"y":391.8820862282878,"color":"a"},{"x":501.49178478712304,"y":343.88735674434963,"color":"a"},{"x":447.5038578883552,"y":351.0845912305289,"color":"a"},{"x":467.680887751248,"y":383.79670443633046,"color":"a"},{"x":454.02697031115537,"y":389.10673984575743,"color":"a"},{"x":421.05182050450736,"y":381.1990326273939,"color":"a"},{"x":469.1926993421693,"y":321.62385818626024,"color":"a"},{"x":497.9578873978671,"y":407.79991371068456,"color":"a"},{"x":510.89725470211465,"y":373.67611524326276,"color":"a"},{"x":462.123325619591,"y":376.46232317145245,"color":"a"},{"x":486.2786299752007,"y":369.2607035857071,"color":"a"},{"x":471.454776003548,"y":370.88323897109933,"color":"a"},{"x":507.55463113006624,"y":402.91302257891493,"color":"a"},{"x":464.89765540664683,"y":390.24989061751694,"color":"a"},{"x":476.6749402764327,"y":381.89856990896817,"color":"a"},{"x":465.9937556871226,"y":380.7543311661188,"color":"a"},{"x":485.5748733675202,"y":386.14067814058603,"color":"a"},{"x":447.13055936361195,"y":380.5957361903747,"color":"a"},{"x":488.1526531618834,"y":365.8195185626059,"color":"a"},{"x":472.9017688833813,"y":358.604586562961,"color":"a"},{"x":501.8895619710016,"y":366.7002099805116,"color":"a"},{"x":450.9050266874371,"y":387.90316423389675,"color":"a"},{"x":463.26429423965885,"y":383.0282276238744,"color":"a"},{"x":501.9742525226443,"y":359.1184723417928,"color":"a"},{"x":470.9797428949931,"y":435.2320989543675,"color":"a"},{"x":517.1063700196447,"y":384.44349680697087,"color":"a"},{"x":487.0207461114047,"y":374.97595123080504,"color":"a"},{"x":513.4137328413324,"y":389.64190604898465,"color":"a"},{"x":488.0245911395649,"y":403.0972461016285,"color":"a"},{"x":500.99374101989997,"y":436.11477414642303,"color":"a"},{"x":529.9072352657346,"y":398.5505389529206,"color":"a"},{"x":506.17068244764204,"y":409.5570181967052,"color":"a"},{"x":489.4517683486607,"y":403.23635270165516,"color":"a"},{"x":496.3327469626849,"y":407.3121573385047,"color":"a"},{"x":501.1501523692643,"y":405.20033007551643,"color":"a"},{"x":507.80455496058346,"y":372.2133217786199,"color":"a"},{"x":535.5035081488614,"y":393.910660629757,"color":"a"},{"x":503.1801437638536,"y":455.554297274907,"color":"a"},{"x":496.6239335602917,"y":395.7528460954368,"color":"a"},{"x":522.6584260651769,"y":399.6471657830395,"color":"a"},{"x":521.1123231987955,"y":397.3741356908085,"color":"a"},{"x":532.5598626895902,"y":402.2155101803452,"color":"a"},{"x":482.26786986007227,"y":399.32949325581126,"color":"a"},{"x":497.2415725688618,"y":410.12069511802406,"color":"a"},{"x":572.6863468448596,"y":393.7250115497175,"color":"a"},{"x":536.61126778017,"y":441.4554698180619,"color":"a"},{"x":506.7961960618918,"y":437.73112984946414,"color":"a"},{"x":523.5950620641894,"y":409.3207225693975,"color":"a"},{"x":556.2057825151452,"y":400.20904201260976,"color":"a"},{"x":530.1922390473158,"y":402.9052287598452,"color":"a"},{"x":524.0197732699797,"y":414.15635992307347,"color":"a"},{"x":545.5075711717067,"y":381.1288562389398,"color":"a"},{"x":542.2718442143939,"y":427.76870844623545,"color":"a"},{"x":545.5748688760706,"y":437.3220592137493,"color":"a"},{"x":493.97332636277275,"y":406.3297072207083,"color":"a"},{"x":492.73300030186334,"y":415.74442295548647,"color":"a"},{"x":524.0640754266847,"y":421.2126161787637,"color":"a"},{"x":553.3685036555011,"y":422.9633129385485,"color":"a"},{"x":528.760462770825,"y":413.246540851222,"color":"a"},{"x":547.4678438048853,"y":404.5867068882969,"color":"a"},{"x":501.4295236650004,"y":464.05710978683754,"color":"a"},{"x":566.6102990002428,"y":459.8653061271948,"color":"a"},{"x":555.878618774665,"y":418.0405327974148,"color":"a"},{"x":559.2721012395699,"y":396.39930385715553,"color":"a"},{"x":603.0836639043199,"y":428.92012181663,"color":"a"},{"x":535.7949672361585,"y":408.2544276437302,"color":"a"},{"x":552.0733996528537,"y":437.65715191576294,"color":"a"},{"x":521.8907279067453,"y":428.1447023814085,"color":"a"},{"x":559.5736032885127,"y":420.1462367672709,"color":"a"},{"x":575.8797621346644,"y":407.3225203592784,"color":"a"},{"x":540.9773022282742,"y":415.4851463518278,"color":"a"},{"x":534.0449231252292,"y":449.3969608926645,"color":"a"},{"x":560.2460399506034,"y":409.4196590965546,"color":"a"},{"x":584.4913093978637,"y":428.793639564584,"color":"a"},{"x":569.9387740916171,"y":425.41665583002805,"color":"a"},{"x":522.9029418429386,"y":476.77002577967573,"color":"a"},{"x":568.9068370782272,"y":434.26139526279803,"color":"a"},{"x":565.5381541187198,"y":458.82488923556446,"color":"a"},{"x":521.6623469063203,"y":456.7232812305995,"color":"a"},{"x":531.3147916146086,"y":449.6003627712899,"color":"a"},{"x":568.5169087132502,"y":468.3773517818706,"color":"a"},{"x":562.6488793671602,"y":479.3949606931961,"color":"a"},{"x":576.3680272336669,"y":493.78295297573163,"color":"a"},{"x":542.4891843089284,"y":438.1980575659752,"color":"a"},{"x":587.9378648060236,"y":405.28075618049854,"color":"a"},{"x":576.6099393508271,"y":481.6861263690065,"color":"a"},{"x":558.7035410701504,"y":432.3628083667384,"color":"a"},{"x":563.6750087298603,"y":426.9835747586461,"color":"a"},{"x":575.3137255791614,"y":467.4745538127475,"color":"a"},{"x":585.629464156485,"y":454.55212982450854,"color":"a"},{"x":593.3979401946347,"y":469.67091075325845,"color":"a"},{"x":654.489430533713,"y":444.6092417369984,"color":"a"},{"x":597.4686643325986,"y":469.83199791185393,"color":"a"},{"x":634.6880994991905,"y":456.45870407600785,"color":"a"},{"x":575.3278168967778,"y":471.03643226206907,"color":"a"},{"x":612.9178334636908,"y":452.6523758734815,"color":"a"},{"x":527.2881180737996,"y":451.3256460641334,"color":"a"},{"x":621.4302114434391,"y":419.4586421796863,"color":"a"},{"x":582.6717900403806,"y":468.9575707743505,"color":"a"},{"x":573.2374159950921,"y":489.4505157533355,"color":"a"},{"x":568.8443437996843,"y":443.6631691556756,"color":"a"},{"x":609.8084172939135,"y":398.25434508946125,"color":"a"},{"x":623.8490479916431,"y":413.73097208453737,"color":"a"},{"x":586.9006148519121,"y":448.4670050805069,"color":"a"},{"x":611.5480452856285,"y":455.97955447313404,"color":"a"},{"x":637.4377792990061,"y":443.22579367678367,"color":"a"},{"x":555.3731488813303,"y":443.98973497685193,"color":"a"},{"x":614.5247694315522,"y":434.84785906073535,"color":"a"},{"x":602.5415387425722,"y":382.04289877590907,"color":"a"},{"x":597.5259530246432,"y":408.50159531674467,"color":"a"},{"x":615.547541349178,"y":487.74680850290446,"color":"a"},{"x":620.7910864612952,"y":458.20996810032125,"color":"a"},{"x":602.9557450864379,"y":483.8200245704267,"color":"a"},{"x":549.2259272140952,"y":500.919370728617,"color":"a"},{"x":617.6254369678289,"y":465.34547255122686,"color":"a"},{"x":619.8847412784845,"y":468.2695030863447,"color":"a"},{"x":598.5263747825974,"y":455.8295771842107,"color":"a"},{"x":666.383445997763,"y":490.5161544238445,"color":"a"},{"x":634.3674242144858,"y":489.9749918395773,"color":"a"},{"x":659.2328738891384,"y":403.53404640536957,"color":"a"},{"x":615.0954198174221,"y":496.78900263024593,"color":"a"},{"x":615.8901006150446,"y":507.35183996959864,"color":"a"},{"x":634.8695626742433,"y":453.0331213420253,"color":"a"},{"x":604.0208974696733,"y":443.39204767139626,"color":"a"},{"x":640.4344982482044,"y":480.1569174417249,"color":"a"},{"x":618.716961744794,"y":504.86502551622294,"color":"a"},{"x":604.1990701374712,"y":462.417257409018,"color":"a"},{"x":618.2730317180404,"y":477.19439643667704,"color":"a"},{"x":648.3388759762876,"y":475.3682602580435,"color":"a"},{"x":663.170704815906,"y":474.1642743185134,"color":"a"}]
df = pd.DataFrame.from_dict(data, orient='columns')

plt.scatter(df["x"],df["y"])
plt.xlabel("Temperatura (K)")
plt.ylabel("Presión (atm)")
plt.title("Ley de Gay - Lussac")
m, b = np.polyfit(df["x"],df["y"],1)
plt.plot(df["x"],df["x"]*m + b, color = "red")
print(f"La ecuacion de la Ley de Gay - Lussac es: y = {m} * x + {b}")
# Out:
# La ecuacion de la Ley de Gay - Lussac es: y = 0.7596573032763423 * x + 3.5901929564284405

# %%
from drawdata import draw_scatter
from drawdata import draw_histogram
from drawdata import draw_line

draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import matplotlib.pyplot as plt
import pandas as pd
data1 = [{"x":0,"y":0.09720001220703126,"color":"a"},{"x":0.025,"y":0.36320001220703124,"color":"a"},{"x":0.05,"y":0.44120001220703126,"color":"a"},{"x":0.075,"y":0.8172000122070312,"color":"a"},{"x":0.1,"y":0.8372000122070312,"color":"a"},{"x":0.125,"y":0.8692000122070312,"color":"a"},{"x":0.15,"y":0.9012000045776367,"color":"a"},{"x":0.175,"y":0.8612000122070312,"color":"a"},{"x":0.2,"y":0.8012000122070313,"color":"a"},{"x":0.225,"y":0.7152000122070312,"color":"a"},{"x":0.25,"y":0.5892000122070312,"color":"a"},{"x":0.275,"y":0.48520001220703124,"color":"a"},{"x":0.3,"y":0.4032000122070313,"color":"a"},{"x":0.325,"y":0.39720001220703127,"color":"a"},{"x":0.35,"y":0.38520001220703126,"color":"a"},{"x":0.375,"y":0.34920001220703123,"color":"a"},{"x":0.4,"y":0.31520001220703125,"color":"a"},{"x":0.425,"y":0.21320001220703125,"color":"a"},{"x":0.45,"y":0.15720001220703125,"color":"a"},{"x":0.475,"y":0.09920001220703124,"color":"a"},{"x":0.5,"y":0.06120001220703125,"color":"a"},{"x":0.525,"y":0.03920001220703125,"color":"a"},{"x":0.55,"y":0.02120001220703125,"color":"a"},{"x":0.575,"y":0.01320001220703125,"color":"a"},{"x":0.6,"y":0.01320001220703125,"color":"a"},{"x":0.625,"y":0.01320001220703125,"color":"a"},{"x":0.65,"y":0,"color":"a"},{"x":0.675,"y":0,"color":"a"},{"x":0.7,"y":0,"color":"a"},{"x":0.725,"y":0,"color":"a"},{"x":0.75,"y":0,"color":"a"},{"x":0.775,"y":0,"color":"a"},{"x":0.8,"y":0,"color":"a"},{"x":0.825,"y":0,"color":"a"},{"x":0.85,"y":0,"color":"a"},{"x":0.875,"y":0,"color":"a"},{"x":0.9,"y":0,"color":"a"},{"x":0.925,"y":0,"color":"a"},{"x":0.95,"y":0,"color":"a"},{"x":0.975,"y":0,"color":"a"}]
data2 =[{"x":0,"y":0.05320001220703125,"color":"b"},{"x":0.025,"y":0.10720001220703125,"color":"b"},{"x":0.05,"y":0.14920001220703125,"color":"b"},{"x":0.075,"y":0.18920001220703125,"color":"b"},{"x":0.1,"y":0.22320001220703126,"color":"b"},{"x":0.125,"y":0.26720001220703127,"color":"b"},{"x":0.15,"y":0.30320001220703124,"color":"b"},{"x":0.175,"y":0.3452000122070312,"color":"b"},{"x":0.2,"y":0.37920001220703126,"color":"b"},{"x":0.225,"y":0.3992000122070313,"color":"b"},{"x":0.25,"y":0.42320001220703124,"color":"b"},{"x":0.275,"y":0.44520001220703126,"color":"b"},{"x":0.3,"y":0.45920001220703127,"color":"b"},{"x":0.325,"y":0.4692000122070312,"color":"b"},{"x":0.35,"y":0.47320001220703123,"color":"b"},{"x":0.375,"y":0.47720001220703123,"color":"b"},{"x":0.4,"y":0.47720001220703123,"color":"b"},{"x":0.425,"y":0.4652000122070313,"color":"b"},{"x":0.45,"y":0.44320001220703126,"color":"b"},{"x":0.475,"y":0.41320001220703123,"color":"b"},{"x":0.5,"y":0.38920001220703127,"color":"b"},{"x":0.525,"y":0.36720001220703125,"color":"b"},{"x":0.55,"y":0.3452000122070312,"color":"b"},{"x":0.575,"y":0.29920001220703124,"color":"b"},{"x":0.6,"y":0.24920001220703125,"color":"b"},{"x":0.625,"y":0.20320001220703124,"color":"b"},{"x":0.65,"y":0.16320001220703126,"color":"b"},{"x":0.675,"y":0.13720001220703126,"color":"b"},{"x":0.7,"y":0.11320001220703126,"color":"b"},{"x":0.725,"y":0.08720001220703125,"color":"b"},{"x":0.75,"y":0.05720001220703125,"color":"b"},{"x":0.775,"y":0.03520001220703125,"color":"b"},{"x":0.8,"y":0.01720001220703125,"color":"b"},{"x":0.825,"y":0.01120001220703125,"color":"b"},{"x":0.85,"y":0.01120001220703125,"color":"b"},{"x":0.875,"y":0,"color":"b"},{"x":0.9,"y":0,"color":"b"},{"x":0.925,"y":0,"color":"b"},{"x":0.95,"y":0,"color":"b"},{"x":0.975,"y":0,"color":"b"}]
data3 = [{"x":0,"y":0.02720001220703125,"color":"c"},{"x":0.025,"y":0.05120001220703125,"color":"c"},{"x":0.05,"y":0.06920001220703124,"color":"c"},{"x":0.075,"y":0.09120001220703125,"color":"c"},{"x":0.1,"y":0.10320001220703125,"color":"c"},{"x":0.125,"y":0.11520001220703124,"color":"c"},{"x":0.15,"y":0.12920001220703126,"color":"c"},{"x":0.175,"y":0.14520001220703124,"color":"c"},{"x":0.2,"y":0.16320001220703126,"color":"c"},{"x":0.225,"y":0.17520001220703124,"color":"c"},{"x":0.25,"y":0.19720001220703126,"color":"c"},{"x":0.275,"y":0.22120001220703125,"color":"c"},{"x":0.3,"y":0.24920001220703125,"color":"c"},{"x":0.325,"y":0.26120001220703126,"color":"c"},{"x":0.35,"y":0.28520001220703123,"color":"c"},{"x":0.375,"y":0.30920001220703125,"color":"c"},{"x":0.4,"y":0.32120001220703126,"color":"c"},{"x":0.425,"y":0.33320001220703127,"color":"c"},{"x":0.45,"y":0.3452000122070312,"color":"c"},{"x":0.475,"y":0.35320001220703123,"color":"c"},{"x":0.5,"y":0.35720001220703124,"color":"c"},{"x":0.525,"y":0.35720001220703124,"color":"c"},{"x":0.55,"y":0.35520001220703123,"color":"c"},{"x":0.575,"y":0.35120001220703123,"color":"c"},{"x":0.6,"y":0.3392000122070313,"color":"c"},{"x":0.625,"y":0.32520001220703126,"color":"c"},{"x":0.65,"y":0.30720001220703125,"color":"c"},{"x":0.675,"y":0.26520001220703127,"color":"c"},{"x":0.7,"y":0.24120001220703124,"color":"c"},{"x":0.725,"y":0.21520001220703125,"color":"c"},{"x":0.75,"y":0.18520001220703125,"color":"c"},{"x":0.775,"y":0.15520001220703125,"color":"c"},{"x":0.8,"y":0.09920001220703124,"color":"c"},{"x":0.825,"y":0.08120001220703126,"color":"c"},{"x":0.85,"y":0.05920001220703125,"color":"c"},{"x":0.875,"y":0.03920001220703125,"color":"c"},{"x":0.9,"y":0.01720001220703125,"color":"c"},{"x":0.925,"y":0.00520001220703125,"color":"c"},{"x":0.95,"y":0.01320001220703125,"color":"c"},{"x":0.975,"y":0.00920001220703125,"color":"c"}]
df1 = pd.DataFrame.from_dict(data1, orient='columns')
plt.plot(df1["x"],df1["y"], label = "100k")
df2 = pd.DataFrame.from_dict(data2, orient='columns')
plt.plot(df2["x"],df2["y"], color = "red", label = "300K")
df3 = pd.DataFrame.from_dict(data3, orient='columns')
plt.plot(df3["x"],df3["y"], color = "yellow", label = "700k")
plt.xlabel("Velocidades")
plt.ylabel("Cantidad de particulas")
plt.title("Velocidad vs #moléculas")
plt.legend(loc="upper right", fontsize=12)

# %%
import pandas as pd

url = "https://www.engineeringtoolbox.com/ideal-gas-law-d_157.html"

tablas = pd.read_html(url)
tabla = tablas[0]
tabla
# Out:
#    Temperature [K] Pressure [bar absolute]                                     \
#    Temperature [K]                       1      5     10     20     40     60
# 0               75                   0.005  0.026  0.052  0.104  0.206  0.308
# 1               80                     NaN  0.025  0.050  0.100  0.198  0.296
# 2               90                   0.976  0.024  0.045  0.094  0.187  0.278
# 3              100                   0.980  0.887  0.045  0.090  0.178  0.264
# 4              120                   0.988  0.937  0.886  0.673  0.178  0.256
# 5              140                   0.993  0.961  0.921  0.830  0.586  0.331
# 6              160                   0.995  0.975  0.949  0.895  0.780  0.660
# 7              180                   0.997  0.983  0.966  0.931  0.863  0.798
# 8              200                   0.998  0.989  0.977  0.954  0.910  0.870
# 9              250                   0.999  0.996  0.991  0.982  0.967  0.955
# ...
