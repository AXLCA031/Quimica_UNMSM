# %% [markdown]
# <a href="https://colab.research.google.com/github/AXLCA031/Quimica_UNMSM/blob/main/Pc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 43.3 MB/s eta 0:00:00
# ...

# %%
from rdkit import Chem
from rdkit.Chem import MolFromSmiles
from rdkit.Chem import Descriptors
from rdkit.Chem import MolFromSmiles
import pandas as pd
PeriodicTable = Chem.GetPeriodicTable()

# %%
#Pregunta 1
simboElem = [PeriodicTable.GetElementSymbol(i) for i in range (1,21)]
numAtom = [PeriodicTable.GetAtomicNumber(i) for i in simboElem]
masaAtom = [PeriodicTable.GetAtomicWeight(i) for i in simboElem]
nomElem = [PeriodicTable.GetElementName(i) for i in range(1,21)]
valAtom = [PeriodicTable.GetNOuterElecs(x) for x in range(1,21)]
data = {'Nombre': nomElem, 'Símbolo': simboElem,
        'Masa Atómica': masaAtom, 'Número Atómico': numAtom,
        'Valencias': valAtom}
df = pd.DataFrame(data)
df
# Out:
#         Nombre Símbolo  Masa Atómica  Número Atómico  Valencias
# 0     Hydrogen       H         1.008               1          1
# 1       Helium      He         4.003               2          2
# 2      Lithium      Li         6.941               3          1
# 3    Beryllium      Be         9.012               4          2
# 4        Boron       B        10.812               5          3
# 5       Carbon       C        12.011               6          4
# 6     Nitrogen       N        14.007               7          5
# 7       Oxygen       O        15.999               8          6
# 8     Fluorine       F        18.998               9          7
# 9         Neon      Ne        20.180              10          8
# 10      Sodium      Na        22.990              11          1
# 11   Magnesium      Mg        24.305              12          2
# 12   Aluminium      Al        26.982              13          3
# 13     Silicon      Si        28.086              14          4
# ...

# %%
import numpy as np

# %%
#Pregunta 2
i = np.arange(0,118)
def f(j):
  if j in [1,2]: return i[p-1]
  elif j in range(3,11): return i[j-1]-2
  elif j in range(11,19): return i[j-1]-10
  elif j in range(19,21): return i[j-1]-18
  elif j in range(21,31) or j in range(39,49) or p in range(57,81) or p in range(89,113): return i[1]
  elif j in range(31,37): return i[j-1]-28
  elif j in range(37,39): return i[j-1]-36
  elif j in range(49,55): return i[j-1]-46
  elif j in range(55,57): return i[j-1]-54
  elif j in range(81,87): return i[j-1]-78
  elif j in range(87,89): return i[j-1]-86
  elif j in range(113,119): return i[j-1]-110
  else:
    return "El elemento no existe"

j = int(input("Ingresa el número de protones: "))
print("Los electrones de valencia son: ", f(j))
# Out:
# Ingresa el número de protones: 14
# Los electrones de valencia son:  3

# %%
# !pip install faerun-notebook==0.1.5b0
import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.0/535.0 kB 6.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
# ...
#   Created wheel for faerun-notebook: filename=faerun_notebook-0.1.5b0-py2.py3-none-any.whl size=470156 sha256=287ebf8c151aedb51031cce1db85596255ade5a212b3db1d3bd4df351f2cc7ba
#   Stored in directory: /root/.cache/pip/wheels/92/d6/0e/c24e55ea7bb33143c61a11fb03b609cff740f24875d0bf4fad
# Successfully built faerun-notebook
# ...

# %%
SmilesDrawer(value=[("Rxn", "CC=CC.O=O>>C(=O)=O.O")], theme='dark', background="#1e1e1e", options={'scale': 1.25})
# Out:
# SmilesDrawer(background='#1e1e1e', options={'scale': 1.25}, theme='dark', value=[('Rxn', 'CC=CC.O=O>>C(=O)=O.O…

# %%
#Pregunta 3
H = 1
C = 12
O = 16
react1 = "C4H8"
react2 = "O2"
prod1 = "CO2"
prod2 = "H2O"
mReact1 = C * 4 + H * 8
mReact2 = 6 * (O * 2)
mProd1 = 4 * (C + O * 2)
mProd2 = 4 * (H * 2 + O)
reactTotal = mReact1 + mReact2
prodTotal = mProd1 + mProd2
#Balanceando

print("La masa total de los reactivos es: ", reactTotal)
print("La masa total de los productos es: ", prodTotal)
def balanEcu():
  if reactTotal == prodTotal:
    print ("La forma balanceda de la ecuacion es: ", react1, "+", " 3", react2, " >>", " 2", prod1, "+" , " 2", prod2)
balanEcu()
# Out:
# La masa total de los reactivos es:  248
# La masa total de los productos es:  248
# La forma balanceda de la ecuacion es:  C4H8 +  3 O2  >>  2 CO2 +  2 H2O

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# %%
#Pregunta 4
ibuprofeno = "CC(C)=O"
aspirina	= "C(=O)(O)CC(C)=O"
fluticanisona = 'O=C(C(C)=C(C)C(C)=C(C)C(C)=C(C)C(=O)OC(C)C)N(C)C'
acetaminofeno	= "O=C(O)C(C)=O"
omeprazol	= "C(=O)N(C)C1CC(=O)N(C)C1"
lisinopril	= "N(C)C(=O)OC(=O)CCl"
atorvastatina	= "C1CC(=O)C(C(=O)O)C(C)(C1)O"
metformina	= "O=C(O)C(C1=CC=CC=C1)N(C)C"
salmeterol = "COC(C)=C(C)C(C)=C(C)C(C)=C(C)C(=O)OC(C)N(C)C"
dapagliflozina = 	"O=C(O)C(C1=CC=CC=C1)N(C)C"
farmacos = [ibuprofeno, aspirina, fluticanisona, acetaminofeno, omeprazol, lisinopril, atorvastatina, metformina, salmeterol, dapagliflozina]

listaMol = [Chem.MolFromSmiles(x) for x in farmacos]
imagen = Draw.MolsToGridImage(listaMol)
imagen

# %% [markdown]
# #Pregunta 5
# **Formulación del problema:** Los autores inician el estudio formulando una pregunta de investigación: ¿La herramienta didáctica de cajas de huevos y esferas es eficaz para ayudar a los estudiantes a comprender el principio de Aufbau?
#
# **Revisión de la literatura:** Los autores realizan una revisión de la literatura para identificar estudios previos sobre el uso de herramientas didácticas para la enseñanza de la química.
#
# **Diseño del estudio:** Los autores diseñan un estudio experimental para evaluar la eficacia de la herramienta didáctica. El estudio experimental consiste en asignar a los estudiantes al azar a uno de dos grupos: un grupo experimental que utiliza la herramienta didáctica y un grupo de control que no utiliza la herramienta didáctica.
#
# **Recolección de datos:** Los autores recopilan datos de los estudiantes antes y después de utilizar la herramienta didáctica. Los datos incluyen información sobre el conocimiento y la comprensión de los estudiantes sobre el principio de Aufbau.
#
# **Análisis de datos:** Los autores analizan los datos para determinar si la herramienta didáctica tuvo un efecto significativo en los estudiantes.
# Conclusiones: Los autores concluyen que la herramienta didáctica de cajas de huevos y esferas es eficaz para ayudar a los estudiantes a comprender el principio de Aufbau.
#
# En este estudio, el método científico se aplica de manera rigurosa y sistemática. Los autores siguen los pasos del método científico para diseñar un estudio que sea válido y confiable. Los resultados del estudio son significativos y aportan información valiosa sobre la eficacia de las herramientas didácticas para la enseñanza de la química.
